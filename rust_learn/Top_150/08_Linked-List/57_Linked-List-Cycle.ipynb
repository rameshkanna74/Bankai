# %% [markdown]
# 141. Linked List Cycle
#      Easy
#      Topics
#      Companies
#
# Given head, the head of a linked list, determine if the linked list has a cycle in it.
#
# There is a cycle in a linked list if there is some node in the list that can be reached again by continuously following the next pointer. Internally, pos is used to denote the index of the node that tail's next pointer is connected to. Note that pos is not passed as a parameter.
#
# Return true if there is a cycle in the linked list. Otherwise, return false.
#
# Example 1:
#
# Input: head = [3,2,0,-4], pos = 1
# Output: true
# Explanation: There is a cycle in the linked list, where the tail connects to the 1st node (0-indexed).
#
# Example 2:
#
# Input: head = [1,2], pos = 0
# Output: true
# Explanation: There is a cycle in the linked list, where the tail connects to the 0th node.
#
# Example 3:
#
# Input: head = [1], pos = -1
# Output: false
# Explanation: There is no cycle in the linked list.
#
# Constraints:
#
#     The number of the nodes in the list is in the range [0, 104].
#     -105 <= Node.val <= 105
#     pos is -1 or a valid index in the linked-list.
#
# Follow up: Can you solve it using O(1) (i.e. constant) memory?
#
# ---
#
# give best time and space complexity code in python,give variables usefull name, add comments to explain the code way more clear,also add code to run example case, use below typing
#
# ---
#
# # Definition for singly-linked list.
#
# # class ListNode:
#
# # def **init**(self, x):
#
# # self.val = x
#
# # self.next = None
#
# class Solution:
# def hasCycle(self, head: Optional[ListNode]) -> bool:

# %% [markdown]
# Here's a solution for detecting a cycle in a linked list, utilizing Floyd's Tortoise and Hare algorithm. This approach runs in O(n) time and uses O(1) space, which is optimal for this problem. The comments explain each part of the code clearly.
#
# ```python
# # Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None
#
# class Solution:
#     def hasCycle(self, head: Optional[ListNode]) -> bool:
#         # Initialize two pointers: tortoise and hare
#         tortoise = head  # The slow pointer moves one step at a time
#         hare = head      # The fast pointer moves two steps at a time
#
#         # Traverse the list until we reach the end or find a cycle
#         while hare is not None and hare.next is not None:
#             tortoise = tortoise.next        # Move tortoise one step
#             hare = hare.next.next           # Move hare two steps
#
#             # Check if the two pointers meet, indicating a cycle
#             if tortoise == hare:
#                 return True  # Cycle detected
#
#         return False  # No cycle found
#
# # Example cases to run
# if __name__ == "__main__":
#     # Create a linked list with a cycle: 3 -> 2 -> 0 -> -4
#     #                                         ^         |
#     #                                         |---------|
#     head1 = ListNode(3)
#     head1.next = ListNode(2)
#     head1.next.next = ListNode(0)
#     head1.next.next.next = ListNode(-4)
#     head1.next.next.next.next = head1.next  # Create a cycle
#
#     # Test case 1
#     solution = Solution()
#     print(solution.hasCycle(head1))  # Output: True
#
#     # Create a linked list without a cycle: 1 -> 2
#     head2 = ListNode(1)
#     head2.next = ListNode(2)
#
#     # Test case 2
#     print(solution.hasCycle(head2))  # Output: False
#
#     # Create a linked list with a cycle: 1 -> 2 -> (points back to 1)
#     head3 = ListNode(1)
#     head3.next = head3  # Create a cycle
#
#     # Test case 3
#     print(solution.hasCycle(head3))  # Output: True
#
#     # Create an empty linked list
#     head4 = None
#
#     # Test case 4
#     print(solution.hasCycle(head4))  # Output: False
# ```
#
# ### Explanation:
#
# 1. **ListNode Class**: Represents a single node in the linked list.
# 2. **hasCycle Method**:
#    - Uses two pointers: `tortoise` moves one step and `hare` moves two steps.
#    - If they meet at some point, a cycle exists.
#    - If `hare` reaches the end of the list (`None`), there's no cycle.
# 3. **Example Cases**: The examples demonstrate cases with and without cycles, and the outputs confirm the expected results.
#
# This code effectively checks for cycles in the linked list while adhering to the constraints given in the problem statement.

# %%
from typing import Optional

class ListNode:
    def __init__(self, value=0, next=None):
        self.value = value
        self.next = next

class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        fast = head
        slow = head

        while fast and fast.next:
            fast = fast.next.next
            slow = slow.next

            if fast == slow:
                return True

        return False

# %% [markdown]
# ```rust
# #[derive(Debug)]
# pub struct ListNode {
#     pub value: i32,
#     pub next: Option<Box<ListNode>>,
# }
#
# impl ListNode {
#     #[inline]
#     fn new(value: i32) -> Self {
#         ListNode { value, next: None }
#     }
# }
#
# pub struct Solution;
#
# impl Solution {
#     pub fn has_cycle(head: Option<Box<ListNode>>) -> bool {
#         let mut fast = head.as_ref();
#         let mut slow = head.as_ref();
#
#         while let (Some(fast_node), Some(slow_node)) = (fast, slow) {
#             fast = fast_node.next.as_ref().and_then(|node| node.next.as_ref());
#             slow = slow_node.next.as_ref();
#
#             if fast == slow {
#                 return true;
#             }
#         }
#
#         false
#     }
# }
# ```
