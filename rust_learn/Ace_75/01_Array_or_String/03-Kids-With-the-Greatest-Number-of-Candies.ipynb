// %% [markdown]
// 1431. Kids With the Greatest Number of Candies
//       Easy
//       Topics
//       Companies
//       Hint
//
// There are n kids with candies. You are given an integer array candies, where each candies[i] represents the number of candies the ith kid has, and an integer extraCandies, denoting the number of extra candies that you have.
//
// Return a boolean array result of length n, where result[i] is true if, after giving the ith kid all the extraCandies, they will have the greatest number of candies among all the kids, or false otherwise.
//
// Note that multiple kids can have the greatest number of candies.
//
// Example 1:
//
// Input: candies = [2,3,5,1,3], extraCandies = 3
// Output: [true,true,true,false,true]
// Explanation: If you give all extraCandies to:
//
// - Kid 1, they will have 2 + 3 = 5 candies, which is the greatest among the kids.
// - Kid 2, they will have 3 + 3 = 6 candies, which is the greatest among the kids.
// - Kid 3, they will have 5 + 3 = 8 candies, which is the greatest among the kids.
// - Kid 4, they will have 1 + 3 = 4 candies, which is not the greatest among the kids.
// - Kid 5, they will have 3 + 3 = 6 candies, which is the greatest among the kids.
//
// Example 2:
//
// Input: candies = [4,2,1,1,2], extraCandies = 1
// Output: [true,false,false,false,false]
// Explanation: There is only 1 extra candy.
// Kid 1 will always have the greatest number of candies, even if a different kid is given the extra candy.
//
// Example 3:
//
// Input: candies = [12,1,12], extraCandies = 10
// Output: [true,false,true]
//
// Constraints:
//
//     n == candies.length
//     2 <= n <= 100
//     1 <= candies[i] <= 100
//     1 <= extraCandies <= 50
//
// ---
//
// give best time and space complexity code in rust,give variables usefull name, add comments to explain the code way more clear,also add code to run example case, use below typing
//
// ---
//
// impl Solution {
// pub fn kids_with_candies(candies: Vec<i32>, extra_candies: i32) -> Vec<bool> {
//
//     }
//
// }

// %%
impl Solution {
    pub fn kids_with_candies(candies: Vec<i32>, extra_candies: i32) -> Vec<bool> {
        let most: i32 = *candies.iter().max().unwrap();
        
        candies.iter().map(|kid| {
            kid + extra_candies >= most
        }).collect()
        
    }
}
// Out:
// [E0412] Error: cannot find type `Solution` in this scope
//    ╭─[command_2:1:1]
//    │
//  1 │ impl Solution {
//    │      ────┬───
//    │          ╰───── not found in this scope
// ───╯

// %% [markdown]
// 1431. Kids With the Greatest Number of Candies
//       Easy
//       Topics
//       Companies
//       Hint
//
// There are n kids with candies. You are given an integer array candies, where each candies[i] represents the number of candies the ith kid has, and an integer extraCandies, denoting the number of extra candies that you have.
//
// Return a boolean array result of length n, where result[i] is true if, after giving the ith kid all the extraCandies, they will have the greatest number of candies among all the kids, or false otherwise.
//
// Note that multiple kids can have the greatest number of candies.
//
// Example 1:
//
// Input: candies = [2,3,5,1,3], extraCandies = 3
// Output: [true,true,true,false,true]
// Explanation: If you give all extraCandies to:
//
// - Kid 1, they will have 2 + 3 = 5 candies, which is the greatest among the kids.
// - Kid 2, they will have 3 + 3 = 6 candies, which is the greatest among the kids.
// - Kid 3, they will have 5 + 3 = 8 candies, which is the greatest among the kids.
// - Kid 4, they will have 1 + 3 = 4 candies, which is not the greatest among the kids.
// - Kid 5, they will have 3 + 3 = 6 candies, which is the greatest among the kids.
//
// Example 2:
//
// Input: candies = [4,2,1,1,2], extraCandies = 1
// Output: [true,false,false,false,false]
// Explanation: There is only 1 extra candy.
// Kid 1 will always have the greatest number of candies, even if a different kid is given the extra candy.
//
// Example 3:
//
// Input: candies = [12,1,12], extraCandies = 10
// Output: [true,false,true]
//
// Constraints:
//
//     n == candies.length
//     2 <= n <= 100
//     1 <= candies[i] <= 100
//     1 <= extraCandies <= 50
//
// ==========
// impl Solution {
//     pub fn kids_with_candies(candies: Vec<i32>, extra_candies: i32) -> Vec<bool> {
//         let most: i32 = *candies.iter().max().unwrap();
//
//         candies.iter().map(|kid| {
//             kid + extra_candies >= most
//         }).collect()
//
//     }
// }
// ==============
// if interviewer ask what is the time and space complexity, what DSA concept i used here why , (knowledge learned from this will help in which condition),also explain why code suitable for this question

// %% [markdown]
// ### Time Complexity
//
// 1. **Finding the Maximum Candies**:
//
//    - `candies.iter().max()` iterates through the entire list once to find the maximum value, which takes \(O(n)\), where \(n\) is the number of kids.
//
// 2. **Mapping Over the List**:
//
//    - The `.map()` function iterates over the list once to check if each kid's candies plus the extra candies are greater than or equal to the maximum. This also takes \(O(n)\).
//
//    **Total Time Complexity**: \(O(n)\).
//
// ---
//
// ### Space Complexity
//
// 1. **Temporary Storage**:
//
//    - The boolean results are stored in a new vector, which takes \(O(n)\) space.
//
// 2. **Iterators**:
//
//    - Iterators are used for both `max()` and `.map()`, which require \(O(1)\) additional space.
//
//    **Total Space Complexity**: \(O(n)\), primarily for the output vector.
//
// ---
//
// ### DSA Concepts Used
//
// 1. **Iterators**:
//
//    - The solution uses iterators (`iter()`, `map()`, and `collect()`), which are powerful abstractions for working with collections in a concise and expressive manner.
//
// 2. **Comparison**:
//
//    - The logic involves comparing each value in the list to a precomputed maximum, a common operation in problems requiring condition-based filtering.
//
// 3. **Greedy Approach**:
//    - By finding the maximum value in advance, the solution efficiently determines whether a condition is met for each kid.
//
// ---
//
// ### Why These Concepts Were Used
//
// 1. **Efficiency**:
//
//    - Calculating the maximum candy count in advance reduces redundant operations. By precomputing the `most`, the solution avoids recalculating the maximum for each kid, making the approach linear.
//
// 2. **Simplicity**:
//    - The use of iterators (`map()` and `collect()`) makes the code concise and readable. Rust's standard library functions handle most of the low-level logic.
//
// ---
//
// ### When This Knowledge Is Useful
//
// 1. **Condition-Based Evaluation**:
//
//    - This approach is useful for problems where a precomputed value (like a maximum or minimum) is used to evaluate a condition across a collection.
//
// 2. **Threshold Problems**:
//
//    - In scenarios where you need to check if elements in a dataset meet a threshold condition, this technique can be applied (e.g., validating scores, budgets, or limits).
//
// 3. **One-Pass Operations**:
//    - Problems requiring a single scan or minimal overhead (like this one) can benefit from this technique.
//
// ---
//
// ### Why the Code Is Suitable for This Question
//
// 1. **Optimal Performance**:
//
//    - The solution leverages a single pass to find the maximum and another to determine which kids meet the condition, ensuring \(O(n)\) time complexity, which is optimal given the constraints.
//
// 2. **Clear Logic**:
//
//    - The code directly reflects the problem statement:
//      - Compute the maximum candies.
//      - Check if each kid's candies + extra candies meet or exceed this maximum.
//
// 3. **Rust-Specific Features**:
//
//    - The use of iterators (`iter()`, `map()`, and `collect()`) makes the code both idiomatic and efficient, demonstrating a strong understanding of Rust's standard library.
//
// 4. **Handles Edge Cases**:
//    - The approach works well for small inputs (minimum 2 kids) and large inputs (up to 100 kids) within the constraints.
//
// ---
//
// ### Key Learning
//
// This solution demonstrates how to:
//
// - Use **iterators** to simplify and optimize problems involving collections.
// - Precompute key values (e.g., maximum or minimum) to reduce redundant calculations.
// - Apply a **greedy approach** to efficiently solve threshold or condition-based problems.
