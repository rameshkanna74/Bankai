# %%
import os

# Define the topics and their respective notebook names
structure = {
    "Graph General": [
        "89-Number-of-Islands.ipynb",
        "90-Surrounded-Regions.ipynb",
        "91-Clone-Graph.ipynb",
        "92-Evaluate-Division.ipynb",
        "93-Course-Schedule.ipynb",
        "94-Course-Schedule-II.ipynb",
    ],
    "Graph BFS": [
        "95-Snakes-and-Ladders.ipynb",
        "96-Minimum-Genetic-Mutation.ipynb",
        "97-Word-Ladder.ipynb",
    ],
    "Trie": [
        "98-Implement-Trie-(Prefix-Tree).ipynb",
        "99-Design-Add-and-Search-Words-Data-Structure.ipynb",
        "100-Word-Search-II.ipynb",
    ],
    "Backtracking": [
        "101-Letter-Combinations-of-a-Phone-Number.ipynb",
        "102-Combinations.ipynb",
        "103-Permutations.ipynb",
        "104-Combination-Sum.ipynb",
        "105-N-Queens-II.ipynb",
        "106-Generate-Parentheses.ipynb",
        "107-Word-Search.ipynb",
    ],
    "Divide & Conquer": [
        "108-Convert-Sorted-Array-to-Binary-Search-Tree.ipynb",
        "109-Sort-List.ipynb",
        "110-Construct-Quad-Tree.ipynb",
        "111-Merge-k-Sorted-Lists.ipynb",
    ],
    "Kadane's Algorithm": [
        "112-Maximum-Subarray.ipynb",
        "113-Maximum-Sum-Circular-Subarray.ipynb",
    ],
    "Binary Search": [
        "114-Search-Insert-Position.ipynb",
        "115-Search-a-2D-Matrix.ipynb",
        "116-Find-Peak-Element.ipynb",
        "117-Search-in-Rotated-Sorted-Array.ipynb",
        "118-Find-First-and-Last-Position-of-Element-in-Sorted-Array.ipynb",
        "119-Find-Minimum-in-Rotated-Sorted-Array.ipynb",
        "120-Median-of-Two-Sorted-Arrays.ipynb",
    ],
    "Heap": [
        "121-Kth-Largest-Element-in-an-Array.ipynb",
        "122-IPO.ipynb",
        "123-Find-K-Pairs-with-Smallest-Sums.ipynb",
        "124-Find-Median-from-Data-Stream.ipynb",
    ],
    "Bit Manipulation": [
        "125-Add-Binary.ipynb",
        "126-Reverse-Bits.ipynb",
        "127-Number-of-1-Bits.ipynb",
        "128-Single-Number.ipynb",
        "129-Single-Number-II.ipynb",
        "130-Bitwise-AND-of-Numbers-Range.ipynb",
    ],
    "Math": [
        "131-Palindrome-Number.ipynb",
        "132-Plus-One.ipynb",
        "133-Factorial-Trailing-Zeroes.ipynb",
        "134-Sqrt(x).ipynb",
        "135-Pow(x,n).ipynb",
        "136-Max-Points-on-a-Line.ipynb",
    ],
    "1D DP": [
        "137-Climbing-Stairs.ipynb",
        "138-House-Robber.ipynb",
        "139-Word-Break.ipynb",
        "140-Coin-Change.ipynb",
        "141-Longest-Increasing-Subsequence.ipynb",
    ],
    "Multidimensional DP": [
        "142-Triangle.ipynb",
        "143-Minimum-Path-Sum.ipynb",
        "144-Unique-Paths-II.ipynb",
        "145-Longest-Palindromic-Substring.ipynb",
        "146-Interleaving-String.ipynb",
        "147-Edit-Distance.ipynb",
        "148-Best-Time-to-Buy-and-Sell-Stock-III.ipynb",
        "149-Best-Time-to-Buy-and-Sell-Stock-IV.ipynb",
        "150-Maximal-Square.ipynb",
    ],
}

# Create directories and files
for topic, notebooks in structure.items():
    # Create the topic folder
    os.makedirs(topic, exist_ok=True)
    for notebook in notebooks:
        # Create the .ipynb file in the corresponding folder
        file_path = os.path.join(topic, notebook)
        with open(file_path, "w") as f:
            f.write(
                '{"cells": [], "metadata": {}, "nbformat": 4, "nbformat_minor": 4}'
            )  # Basic notebook structure

print("Folders and notebooks created successfully!")

# %%
structure = {
    "Data Filtering": [
        "595-Big-Countries.ipynb",
        "1757-Recyclable-and-Low-Fat-Products.ipynb",
        "183-Customers-Who-Never-Order.ipynb",
        "1148-Article-Views-I.ipynb",
    ],
    "String Methods": [
        "1683-Invalid-Tweets.ipynb",
        "1873-Calculate-Special-Bonus.ipynb",
        "1667-Fix-Names-in-a-Table.ipynb",
        "1517-Find-Users-With-Valid-E-Mails.ipynb",
        "1527-Patients-With-a-Condition.ipynb",
    ],
    "Data Manipulation": [
        "177-Nth-Highest-Salary.ipynb",
        "176-Second-Highest-Salary.ipynb",
        "184-Department-Highest-Salary.ipynb",
        "178-Rank-Scores.ipynb",
        "196-Delete-Duplicate-Emails.ipynb",
        "1795-Rearrange-Products-Table.ipynb",
    ],
    "Statistics": [
        "2082-The-Number-of-Rich-Customers.ipynb",
        "1173-Immediate-Food-Delivery-I.ipynb",
        "1907-Count-Salary-Categories.ipynb",
    ],
    "Data Aggregation": [
        "1741-Find-Total-Time-Spent-by-Each-Employee.ipynb",
        "511-Game-Play-Analysis-I.ipynb",
        "2356-Number-of-Unique-Subjects-Taught-by-Each-Teacher.ipynb",
        "596-Classes-More-Than-5-Students.ipynb",
        "586-Customer-Placing-the-Largest-Number-of-Orders.ipynb",
        "1484-Group-Sold-Products-By-The-Date.ipynb",
        "1693-Daily-Leads-and-Partners.ipynb",
    ],
    "Data Integration": [
        "1050-Actors-and-Directors-Who-Cooperated-At-Least-Three-Times.ipynb",
        "1378-Replace-Employee-ID-With-The-Unique-Identifier.ipynb",
        "1280-Students-and-Examinations.ipynb",
        "570-Managers-with-at-Least-5-Direct-Reports.ipynb",
        "607-Sales-Person.ipynb",
    ],
    "Strengthen Your Learning by Solving this Question": [
        "1322-Ads-Performance.ipynb",
        "2041-Accepted-Candidates-From-the-Interviews.ipynb",
        "2738-Count-Occurrences-in-Text.ipynb",
    ],
}

# %%
import shutil

# Original file name
original_file = '2025_jan_01.ipynb'

# Loop to create copies for the next 30 days
for day in range(2, 32):
    # Construct the new file name
    new_file = f'2025_jan_{day:02d}.ipynb'
    
    # Copy the original file to the new file
    shutil.copy(original_file, new_file)
    print(f'Copied {original_file} to {new_file}')

# %%
import shutil
import os

# Take the original file path as input
original_file_path = input("Enter the path of the original file (e.g., /path/to/2025_jan_01.ipynb): ")

# Check if the provided file path exists
if not os.path.isfile(original_file_path):
    print("The specified file does not exist. Please check the file path and try again.")
else:
    # Get the file name from the file path
    original_file_name = os.path.basename(original_file_path)

    # Loop to create copies for the next 30 days
    for day in range(2, 31):
        # Construct the new file name
        # new_file_name = f'2025_jan_{day:02d}.ipynb'
        new_file_name = f'pandas_{day:02d}.ipynb'

        # Construct the new file path
        new_file_path = os.path.join(os.path.dirname(original_file_path), new_file_name)

        # Copy the original file to the new file path
        shutil.copy(original_file_path, new_file_path)
        print(f'Copied {original_file_name} to {new_file_name}')

# %% [markdown]
# /home/kanna/Django/dev/drf/Bankai/rust_learn/Daily_work/2025_02/2025_feb_01.ipynb
# /home/kanna/Django/dev/drf/Bankai/postgres/leetcode_SQL_50/sql_01.ipynb
# /home/kanna/Django/dev/drf/Bankai/postgres/30_day_pandas/pandas_01.ipynb

# %%
import os
import shutil

# Define the topics and their respective notebook names
structure = {
    "Data Filtering": [
        "595-Big-Countries.ipynb",
        "1757-Recyclable-and-Low-Fat-Products.ipynb",
        "183-Customers-Who-Never-Order.ipynb",
        "1148-Article-Views-I.ipynb",
    ],
    "String Methods": [
        "1683-Invalid-Tweets.ipynb",
        "1873-Calculate-Special-Bonus.ipynb",
        "1667-Fix-Names-in-a-Table.ipynb",
        "1517-Find-Users-With-Valid-E-Mails.ipynb",
        "1527-Patients-With-a-Condition.ipynb",
    ],
    "Data Manipulation": [
        "177-Nth-Highest-Salary.ipynb",
        "176-Second-Highest-Salary.ipynb",
        "184-Department-Highest-Salary.ipynb",
        "178-Rank-Scores.ipynb",
        "196-Delete-Duplicate-Emails.ipynb",
        "1795-Rearrange-Products-Table.ipynb",
    ],
    "Statistics": [
        "2082-The-Number-of-Rich-Customers.ipynb",
        "1173-Immediate-Food-Delivery-I.ipynb",
        "1907-Count-Salary-Categories.ipynb",
    ],
    "Data Aggregation": [
        "1741-Find-Total-Time-Spent-by-Each-Employee.ipynb",
        "511-Game-Play-Analysis-I.ipynb",
        "2356-Number-of-Unique-Subjects-Taught-by-Each-Teacher.ipynb",
        "596-Classes-More-Than-5-Students.ipynb",
        "586-Customer-Placing-the-Largest-Number-of-Orders.ipynb",
        "1484-Group-Sold-Products-By-The-Date.ipynb",
        "1693-Daily-Leads-and-Partners.ipynb",
    ],
    "Data Integration": [
        "1050-Actors-and-Directors-Who-Cooperated-At-Least-Three-Times.ipynb",
        "1378-Replace-Employee-ID-With-The-Unique-Identifier.ipynb",
        "1280-Students-and-Examinations.ipynb",
        "570-Managers-with-at-Least-5-Direct-Reports.ipynb",
        "607-Sales-Person.ipynb",
    ],
    "Strengthen Your Learning by Solving this Question": [
        "1322-Ads-Performance.ipynb",
        "2041-Accepted-Candidates-From-the-Interviews.ipynb",
        "2738-Count-Occurrences-in-Text.ipynb",
    ],
}

# Base template file
template_file = 'base_template.ipynb'

# Get the directory of the template file
base_dir = os.path.dirname(template_file)

# Create directories and files using the template
for topic, notebooks in structure.items():
    # Create the topic folder inside the same directory as the template
    topic_dir = os.path.join(base_dir, topic)
    os.makedirs(topic_dir, exist_ok=True)
    for notebook in notebooks:
        # Create the .ipynb file in the corresponding folder
        file_path = os.path.join(topic_dir, notebook)
        shutil.copy(template_file, file_path)
        print(f'Created {file_path} using {template_file} as template.')

print("Folders and notebooks created successfully!")

# %%
import os
import shutil

# Define the topics and their respective notebook names
structure = {
    "01_Data Filtering": [
        "01_pandas-595-Big-Countries.ipynb",
        "02_pandas-1757-Recyclable-and-Low-Fat-Products.ipynb",
        "03_pandas-183-Customers-Who-Never-Order.ipynb",
        "04_pandas-1148-Article-Views-I.ipynb",
    ],
    "02_String Methods": [
        "05_pandas-1683-Invalid-Tweets.ipynb",
        "06_pandas-1873-Calculate-Special-Bonus.ipynb",
        "07_pandas-1667-Fix-Names-in-a-Table.ipynb",
        "08_pandas-1517-Find-Users-With-Valid-E-Mails.ipynb",
        "09_pandas-1527-Patients-With-a-Condition.ipynb",
    ],
    "03_Data Manipulation": [
        "10_pandas-177-Nth-Highest-Salary.ipynb",
        "11_pandas-176-Second-Highest-Salary.ipynb",
        "12_pandas-184-Department-Highest-Salary.ipynb",
        "13_pandas-178-Rank-Scores.ipynb",
        "14_pandas-196-Delete-Duplicate-Emails.ipynb",
        "15_pandas-1795-Rearrange-Products-Table.ipynb",
    ],
    "04_Statistics": [
        "16_pandas-2082-The-Number-of-Rich-Customers.ipynb",
        "17_pandas-1173-Immediate-Food-Delivery-I.ipynb",
        "18_pandas-1907-Count-Salary-Categories.ipynb",
    ],
    "05_Data Aggregation": [
        "19_pandas-1741-Find-Total-Time-Spent-by-Each-Employee.ipynb",
        "20_pandas-511-Game-Play-Analysis-I.ipynb",
        "21_pandas-2356-Number-of-Unique-Subjects-Taught-by-Each-Teacher.ipynb",
        "22_pandas-596-Classes-More-Than-5-Students.ipynb",
        "23_pandas-586-Customer-Placing-the-Largest-Number-of-Orders.ipynb",
        "24_pandas-1484-Group-Sold-Products-By-The-Date.ipynb",
        "25_pandas-1693-Daily-Leads-and-Partners.ipynb",
    ],
    "06_Data Integration": [
        "26_pandas-1050-Actors-and-Directors-Who-Cooperated-At-Least-Three-Times.ipynb",
        "27_pandas-1378-Replace-Employee-ID-With-The-Unique-Identifier.ipynb",
        "28_pandas-1280-Students-and-Examinations.ipynb",
        "29_pandas-570-Managers-with-at-Least-5-Direct-Reports.ipynb",
        "30_pandas-607-Sales-Person.ipynb",
    ],
    "07_Strengthen Your Learning by Solving this Question": [
        "31_pandas-1322-Ads-Performance.ipynb",
        "32_pandas-2041-Accepted-Candidates-From-the-Interviews.ipynb",
        "33_pandas-2738-Count-Occurrences-in-Text.ipynb",
    ],
}

# Base template file
template_file = '/home/kanna/Django/dev/drf/Bankai/postgres/30_day_pandas/pandas_01.ipynb'

# Get the directory of the template file
base_dir = os.path.dirname(template_file)

# Create directories and files using the template
for topic, notebooks in structure.items():
    # Create the topic folder inside the same directory as the template
    topic_dir = os.path.join(base_dir, topic)
    os.makedirs(topic_dir, exist_ok=True)
    for notebook in notebooks:
        # Create the .ipynb file in the corresponding folder
        file_path = os.path.join(topic_dir, notebook)
        shutil.copy(template_file, file_path)
        print(f'Created {file_path} using {template_file} as template.')

print("Folders and notebooks created successfully!")

# %%
import os
import shutil

# Define the topics and their respective notebook names
structure = {
    "01_Data Filtering": [
        "01_pandas-595-Big-Countries.ipynb",
        "02_pandas-1757-Recyclable-and-Low-Fat-Products.ipynb",
        "03_pandas-183-Customers-Who-Never-Order.ipynb",
        "04_pandas-1148-Article-Views-I.ipynb",
    ],
    "02_String Methods": [
        "05_pandas-1683-Invalid-Tweets.ipynb",
        "06_pandas-1873-Calculate-Special-Bonus.ipynb",
        "07_pandas-1667-Fix-Names-in-a-Table.ipynb",
        "08_pandas-1517-Find-Users-With-Valid-E-Mails.ipynb",
        "09_pandas-1527-Patients-With-a-Condition.ipynb",
    ],
    "03_Data Manipulation": [
        "10_pandas-177-Nth-Highest-Salary.ipynb",
        "11_pandas-176-Second-Highest-Salary.ipynb",
        "12_pandas-184-Department-Highest-Salary.ipynb",
        "13_pandas-178-Rank-Scores.ipynb",
        "14_pandas-196-Delete-Duplicate-Emails.ipynb",
        "15_pandas-1795-Rearrange-Products-Table.ipynb",
    ],
    "04_Statistics": [
        "16_pandas-2082-The-Number-of-Rich-Customers.ipynb",
        "17_pandas-1173-Immediate-Food-Delivery-I.ipynb",
        "18_pandas-1907-Count-Salary-Categories.ipynb",
    ],
    "05_Data Aggregation": [
        "19_pandas-1741-Find-Total-Time-Spent-by-Each-Employee.ipynb",
        "20_pandas-511-Game-Play-Analysis-I.ipynb",
        "21_pandas-2356-Number-of-Unique-Subjects-Taught-by-Each-Teacher.ipynb",
        "22_pandas-596-Classes-More-Than-5-Students.ipynb",
        "23_pandas-586-Customer-Placing-the-Largest-Number-of-Orders.ipynb",
        "24_pandas-1484-Group-Sold-Products-By-The-Date.ipynb",
        "25_pandas-1693-Daily-Leads-and-Partners.ipynb",
    ],
    "06_Data Integration": [
        "26_pandas-1050-Actors-and-Directors-Who-Cooperated-At-Least-Three-Times.ipynb",
        "27_pandas-1378-Replace-Employee-ID-With-The-Unique-Identifier.ipynb",
        "28_pandas-1280-Students-and-Examinations.ipynb",
        "29_pandas-570-Managers-with-at-Least-5-Direct-Reports.ipynb",
        "30_pandas-607-Sales-Person.ipynb",
    ],
    "07_Strengthen Your Learning by Solving this Question": [
        "31_pandas-1322-Ads-Performance.ipynb",
        "32_pandas-2041-Accepted-Candidates-From-the-Interviews.ipynb",
        "33_pandas-2738-Count-Occurrences-in-Text.ipynb",
    ],
}

# Base template file
template_file = "/home/kanna/Django/dev/drf/Bankai/postgres/leetcode_SQL_50/sql_01.ipynb"
# Get the directory of the template file
base_dir = os.path.dirname(template_file)

# Create directories and files using the template
for topic, notebooks in structure.items():
    # Create the topic folder inside the same directory as the template
    topic_dir = os.path.join(base_dir, topic)
    os.makedirs(topic_dir, exist_ok=True)
    for notebook in notebooks:
        # Create the .ipynb file in the corresponding folder
        file_path = os.path.join(topic_dir, notebook)
        shutil.copy(template_file, file_path)
        print(f'Created {file_path} using {template_file} as template.')

print("Folders and notebooks created successfully!")

# %% [markdown]
# /home/kanna/Django/dev/drf/Bankai/postgres/leetcode_SQL_50/sql_01.ipynb

# %%
import os
import shutil


structure = {
    "01_Select": [
        "01_sql-1757-Recyclable-and-Low-Fat-Products.ipynb",
        "02_sql-584-Find-Customer-Referee.ipynb",
        "03_sql-595-Big-Countries.ipynb",
        "04_sql-1148-Article-Views-I.ipynb",
        "05_sql-1683-Invalid-Tweets.ipynb",
    ],
    "02_Basic Joins": [
        "06_sql-1378-Replace-Employee-ID-With-The-Unique-Identifier.ipynb",
        "07_sql-1068-Product-Sales-Analysis-I.ipynb",
        "08_sql-1581-Customer-Who-Visited-but-Did-Not-Make-Any-Transactions.ipynb",
        "09_sql-197-Rising-Temperature.ipynb",
        "10_sql-1661-Average-Time-of-Process-per-Machine.ipynb",
        "11_sql-577-Employee-Bonus.ipynb",
        "12_sql-1280-Students-and-Examinations.ipynb",
        "13_sql-570-Managers-with-at-Least-5-Direct-Reports.ipynb",
        "14_sql-1934-Confirmation-Rate.ipynb",
    ],
    "03_Basic Aggregate Functions": [
        "15_sql-620-Not-Boring-Movies.ipynb",
        "16_sql-1251-Average-Selling-Price.ipynb",
        "17_sql-1075-Project-Employees-I.ipynb",
        "18_sql-1633-Percentage-of-Users-Attended-a-Contest.ipynb",
        "19_sql-1211-Queries-Quality-and-Percentage.ipynb",
        "20_sql-1193-Monthly-Transactions-I.ipynb",
        "21_sql-1174-Immediate-Food-Delivery-II.ipynb",
        "22_sql-550-Game-Play-Analysis-IV.ipynb",
    ],
    "04_Sorting and Grouping": [
        "23_sql-2356-Number-of-Unique-Subjects-Taught-by-Each-Teacher.ipynb",
        "24_sql-1141-User-Activity-for-the-Past-30-Days-I.ipynb",
        "25_sql-1070-Product-Sales-Analysis-III.ipynb",
        "26_sql-596-Classes-More-Than-5-Students.ipynb",
        "27_sql-1729-Find-Followers-Count.ipynb",
        "28_sql-619-Biggest-Single-Number.ipynb",
        "29_sql-1045-Customers-Who-Bought-All-Products.ipynb",
    ],
    "05_Advanced Select and Joins": [
        "30_sql-1731-The-Number-of-Employees-Which-Report-to-Each-Employee.ipynb",
        "31_sql-1789-Primary-Department-for-Each-Employee.ipynb",
        "32_sql-610-Triangle-Judgement.ipynb",
        "33_sql-180-Consecutive-Numbers.ipynb",
        "34_sql-1164-Product-Price-at-a-Given-Date.ipynb",
        "35_sql-1204-Last-Person-to-Fit-in-the-Bus.ipynb",
        "36_sql-1907-Count-Salary-Categories.ipynb",
    ],
    "06_Subqueries": [
        "37_sql-1978-Employees-Whose-Manager-Left-the-Company.ipynb",
        "38_sql-626-Exchange-Seats.ipynb",
        "39_sql-1341-Movie-Rating.ipynb",
        "40_sql-1321-Restaurant-Growth.ipynb",
        "41_sql-602-Friend-Requests-II-Who-Has-the-Most-Friends.ipynb",
        "42_sql-585-Investments-in-2016.ipynb",
        "43_sql-185-Department-Top-Three-Salaries.ipynb",
    ],
    "07_Advanced String Functions / Regex / Clause": [
        "44_sql-1667-Fix-Names-in-a-Table.ipynb",
        "45_sql-1527-Patients-With-a-Condition.ipynb",
        "46_sql-196-Delete-Duplicate-Emails.ipynb",
        "47_sql-176-Second-Highest-Salary.ipynb",
        "48_sql-1484-Group-Sold-Products-By-The-Date.ipynb",
        "49_sql-1327-List-the-Products-Ordered-in-a-Period.ipynb",
        "50_sql-1517-Find-Users-With-Valid-E-Mails.ipynb",
    ],
}

template_file = (
    "/home/kanna/Django/dev/drf/Bankai/postgres/leetcode_SQL_50/sql_01.ipynb"
)
# Get the directory of the template file
base_dir = os.path.dirname(template_file)

# Create directories and files using the template
for topic, notebooks in structure.items():
    # Create the topic folder inside the same directory as the template
    topic_dir = os.path.join(base_dir, topic)
    os.makedirs(topic_dir, exist_ok=True)
    for notebook in notebooks:
        # Create the .ipynb file in the corresponding folder
        file_path = os.path.join(topic_dir, notebook)
        shutil.copy(template_file, file_path)
        print(f"Created {file_path} using {template_file} as template.")

print("Folders and notebooks created successfully!")
