# %% [markdown]
# 2530. Maximal Score After Applying K Operations
#       Medium
#       Topics
#       Companies
#       Hint
#
# You are given a 0-indexed integer array nums and an integer k. You have a starting score of 0.
#
# In one operation:
#
#     choose an index i such that 0 <= i < nums.length,
#     increase your score by nums[i], and
#     replace nums[i] with ceil(nums[i] / 3).
#
# Return the maximum possible score you can attain after applying exactly k operations.
#
# The ceiling function ceil(val) is the least integer greater than or equal to val.
#
# Example 1:
#
# Input: nums = [10,10,10,10,10], k = 5
# Output: 50
# Explanation: Apply the operation to each array element exactly once. The final score is 10 + 10 + 10 + 10 + 10 = 50.
#
# Example 2:
#
# Input: nums = [1,10,3,3,3], k = 3
# Output: 17
# Explanation: You can do the following operations:
# Operation 1: Select i = 1, so nums becomes [1,4,3,3,3]. Your score increases by 10.
# Operation 2: Select i = 1, so nums becomes [1,2,3,3,3]. Your score increases by 4.
# Operation 3: Select i = 2, so nums becomes [1,1,1,3,3]. Your score increases by 3.
# The final score is 10 + 4 + 3 = 17.
#
# Constraints:
#
#     1 <= nums.length, k <= 105
#     1 <= nums[i] <= 109
#
# ---
#
# give best time and space complexity code in rust,give variables usefull name, add comments to explain the code way more clear,also add code to run example case, use below typing
#
# ---
#
# impl Solution {
# pub fn max_kelements(nums: Vec<i32>, k: i32) -> i64 {
#
#     }
#
# }

# %%
use std::collections::BinaryHeap;

impl Solution {
    pub fn max_kelements(nums: Vec<i32>, k: i32) -> i64 {
        let mut h: BinaryHeap<i32> = BinaryHeap::from(nums);
        let mut ans: i64 = 0;
        let mut v: i32 = 0;

        for i in 0..k { 
            v = h.pop().unwrap();
            ans += v as i64;
            h.push((v+2)/3);
        }
        ans
    }
}

# %% [markdown]
# https://leetcode.com/discuss/interview-question/5886397/dsa-patterns-you-need-to-know/2672752

# %% [markdown]
# \documentclass[10pt]{deedy-resume-reversed}
# \usepackage{fancyhdr}
# \usepackage{enumitem}
# \usepackage{hyperref}
# \usepackage{xcolor} % For color customization
#
# \pagestyle{fancy}
# \fancyhf{}
# \setlist[itemize]{noitemsep, topsep=0pt} % Reduce spacing in itemize
#
# \begin{document}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     TITLE NAME
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \begin{center}
#     {\Huge Ramesh Kanna} \\
#     \href{mailto:rameshkanna788@gmail.com}{rameshkanna788@gmail.com} | \href{tel:6374675973}{637-467-5973} \\
#     \vspace{0.5em}
#     \hrule
# \end{center}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     COLUMN ONE
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \begin{minipage}[t]{0.60\textwidth}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     SUMMARY
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \section{Summary}
# Dynamic Python developer skilled in Django, FastAPI, and REST APIs, dedicated to building scalable web applications with a focus on clean code and performance. Experienced in integrating advanced OCR technologies and prompt engineering to enhance text recognition capabilities.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     EXPERIENCE
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \section{Experience}
# \runsubsection{Pixirus}
# \descript{| Python Developer}
# \location{Oct 2023 – Present | Puducherry, India}
# \begin{itemize}
#     \item Led digitization of 10,000+ historical texts using custom OCR models, enhancing accessibility.
#     \item Optimized Kraken OCR models with CUDA in local and cloud environments.
#     \item Managed data collection and preprocessing to improve handwriting recognition accuracy.
#     \item Utilized Linux for seamless development and deployment.
# \end{itemize}
# \sectionsep
#
# \runsubsection{Twilight IT Solutions}
# \descript{| Python Developer}
# \location{Nov 2022 – Jul 2023 | Puducherry, India}
# \begin{itemize}
#     \item Developed web applications with Django and PostgreSQL, focusing on user experience.
#     \item Containerized applications using Docker for consistent development and production environments.
#     \item Integrated Celery for asynchronous tasks, improving background processing efficiency.
#     \item Optimized database queries for enhanced application performance.
# \end{itemize}
# \sectionsep
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     SKILLS
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \section{Skills}
# \textbf{Programming Languages:} Python, JavaScript, HTML \\
# \textbf{Frameworks:} Django, FastAPI, Alpine.js, Tailwind CSS \\
# \textbf{Databases:} PostgreSQL, MongoDB, MySQL \\
# \textbf{Tools \& Technologies:} REST API, Git, Docker, OpenCV, OCR, NumPy, Pandas, Matplotlib, Tesseract, Prompt Engineering
# \sectionsep
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     EDUCATION
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \section{Education}
# \subsection{Christ Institute of Technology}
# \descript{B.Tech in Electronics and Communication Engineering}
# \location{Jul 2018 – Aug 2022 | Puducherry, India}
# \location{CGPA: 8.01}
# \sectionsep
#
# \subsection{V.O.C. Govt Higher Secondary School}
# \descript{Higher Secondary Certificate}
# \location{Jun 2017 – Mar 2018 | Puducherry, India}
# \location{Percentage: 61\%}
# \sectionsep
#
# \subsection{Mutharaiyar Higher Secondary School}
# \descript{Secondary School Leaving Certificate}
# \location{Jun 2015 – Apr 2016 | Puducherry, India}
# \location{Percentage: 94\%}
# \sectionsep
#
# \end{minipage}
# \hfill
# \begin{minipage}[t]{0.33\textwidth}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     LINKS
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \section{Links}
# \textbf{LeetCode:}\href{https://leetcode.com/u/rameshkanna74/}{rameshkanna74} \\
# \textbf{GitHub:} \href{https://github.com/rameshkanna74}{rameshKanna74} \\
# \textbf{LinkedIn:} \href{https://www.linkedin.com/in/ramesh-kanna-046142241/}{rameshkanna}
# \sectionsep
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     PROJECTS
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \section{Projects}
# \runsubsection{Desktop OCR Application}
# \descript{| Python Developer}
# \location{2024}
# \begin{itemize}
#     \item Created a desktop app using EasyOCR, Google Document AI, and Azure OCR for streamlined text recognition.
#     \item Integrated multiple OCR technologies to ensure user-friendly experience and accuracy.
# \end{itemize}
# \sectionsep
#
# \runsubsection{Asynchronous Task Scheduling Web Application}
# \descript{| Python Developer}
# \location{2023}
# \begin{itemize}
#     \item Built a web app with Django and PostgreSQL, enhancing user experience and performance.
#     \item Used Celery and Redis for efficient asynchronous task processing.
#     \item Streamlined deployment with Docker and Ansible for configuration management.
# \end{itemize}
# \sectionsep
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     LANGUAGES
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \section{Languages}
# \begin{itemize}
#     \item \textbf{Tamil:} Native or Bilingual Proficiency
#     \item \textbf{English:} Professional Proficiency
#     \item \textbf{Japanese:} Conversational Level (NAT 3Q Certification)
# \end{itemize}
# \sectionsep
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %     INTERESTS
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \section{Interests}
# \begin{itemize}
#     \item Learning Rust to broaden programming paradigms.
#     \item Practicing calisthenics for physical fitness and discipline.
#     \item Exploring machine learning concepts and applications.
#     \item Building custom PCs to enhance technical skills and understanding of hardware.
# \end{itemize}
#
# \end{minipage}
# \end{document}

# %% [markdown]
# To create a Google Docs version of your resume in Japanese, follow these steps:
#
# 1. **Open Google Docs**: Go to [Google Docs](https://docs.google.com).
# 2. **Create a New Document**: Click on the "+" button to start a new document.
# 3. **Copy and Paste the Content**: Use the following formatted text for your resume:
#
# ---
#
# # ラメッシュ・カンナ
#
# [rameshkanna788@gmail.com](mailto:rameshkanna788@gmail.com) | 637-467-5973
#
# ---
#
# ## 概要
#
# ダイナミックな Python 開発者で、Django、FastAPI、および REST API に熟練しており、クリーンなコードとパフォーマンスに重点を置いたスケーラブルな Web アプリケーションの構築に専念しています。高度な OCR 技術とプロンプトエンジニアリングを統合し、テキスト認識能力を向上させる経験があります。
#
# ## 職歴
#
# ### Pixirus
#
# **Python 開発者**
# 2023 年 10 月 – 現在 | プドゥッチェリ、インド
#
# - カスタム OCR モデルを使用して 10,000 以上の歴史的テキストをデジタル化し、アクセス性を向上させました。
# - ローカルおよびクラウド環境で CUDA を使用して Kraken OCR モデルを最適化しました。
# - 手書き認識の精度を向上させるためのデータ収集と前処理を管理しました。
# - シームレスな開発とデプロイメントのために Linux を利用しました。
#
# ### Twilight IT Solutions
#
# **Python 開発者**
# 2022 年 11 月 – 2023 年 7 月 | プドゥッチェリ、インド
#
# - ユーザーエクスペリエンスに焦点を当てた Django と PostgreSQL を使用した Web アプリケーションを開発しました。
# - 一貫した開発および本番環境のために Docker を使用してアプリケーションをコンテナ化しました。
# - 非同期タスクのために Celery を統合し、バックグラウンド処理の効率を改善しました。
# - アプリケーションのパフォーマンスを向上させるためにデータベースクエリを最適化しました。
#
# ## スキル
#
# - **プログラミング言語**: Python, JavaScript, HTML
# - **フレームワーク**: Django, FastAPI, Alpine.js, Tailwind CSS
# - **データベース**: PostgreSQL, MongoDB, MySQL
# - **ツールと技術**: REST API, Git, Docker, OpenCV, OCR, NumPy, Pandas, Matplotlib, Tesseract, プロンプトエンジニアリング
#
# ## 学歴
#
# ### クリスト工科大学
#
# **電子通信工学の学士号**
# 2018 年 7 月 – 2022 年 8 月 | プドゥッチェリ、インド
# CGPA: 8.01
#
# ### V.O.C.政府高等中等学校
#
# **高等学校証明書**
# 2017 年 6 月 – 2018 年 3 月 | プドゥッチェリ、インド
# 割合: 61%
#
# ### ムタライヤール高等中等学校
#
# **中学校卒業証明書**
# 2015 年 6 月 – 2016 年 4 月 | プドゥッチェリ、インド
# 割合: 94%
#
# ## リンク
#
# - **LeetCode**: [rameshkanna74](https://leetcode.com/u/rameshkanna74/)
# - **GitHub**: [rameshKanna74](https://github.com/rameshkanna74)
# - **LinkedIn**: [ramesh-kanna](https://www.linkedin.com/in/ramesh-kanna-046142241/)
#
# ## プロジェクト
#
# ### デスクトップ OCR アプリケーション
#
# **Python 開発者**
# 2024 年
#
# - EasyOCR、Google Document AI、および Azure OCR を使用して、テキスト認識を効率化するデスクトップアプリを作成しました。
# - ユーザーフレンドリーな体験と精度を確保するために、複数の OCR 技術を統合しました。
#
# ### 非同期タスクスケジューリング Web アプリケーション
#
# **Python 開発者**
# 2023 年
#
# - Django と PostgreSQL を使用して Web アプリを構築し、ユーザーエクスペリエンスとパフォーマンスを向上させました。
# - 効率的な非同期タスク処理のために Celery と Redis を使用しました。
# - Docker と Ansible を使用してデプロイメントを簡素化しました。
#
# ## 言語
#
# - **タミル語**: ネイティブまたはバイリンガルの能力
# - **英語**: プロフェッショナルの能力
# - **日本語**: 会話レベル（NAT 3Q 認定）
#
# ## 興味
#
# - プログラミングのパラダイムを広げるために Rust を学ぶこと。
# - 身体的健康と規律のためにカリステニクスを実践すること。
# - 機械学習の概念と応用を探求すること。
# - 技術スキルとハードウェアの理解を深めるためにカスタム PC を構築すること。
#
# ---
#
# 4. **Format the Document**: Adjust fonts, sizes, and alignments as needed to make it visually appealing.
# 5. **Save and Share**: Save the document and share it as needed.
#
# If you need help with specific formatting options or anything else, let me know!
