// %% [markdown]
// 2406. Divide Intervals Into Minimum Number of Groups
//       Medium
//       Topics
//       Companies
//       Hint
//
// You are given a 2D integer array intervals where intervals[i] = [lefti, righti] represents the inclusive interval [lefti, righti].
//
// You have to divide the intervals into one or more groups such that each interval is in exactly one group, and no two intervals that are in the same group intersect each other.
//
// Return the minimum number of groups you need to make.
//
// Two intervals intersect if there is at least one common number between them. For example, the intervals [1, 5] and [5, 8] intersect.
//
// Example 1:
//
// Input: intervals = [[5,10],[6,8],[1,5],[2,3],[1,10]]
// Output: 3
// Explanation: We can divide the intervals into the following groups:
//
// - Group 1: [1, 5], [6, 8].
// - Group 2: [2, 3], [5, 10].
// - Group 3: [1, 10].
//   It can be proven that it is not possible to divide the intervals into fewer than 3 groups.
//
// Example 2:
//
// Input: intervals = [[1,3],[5,6],[8,10],[11,13]]
// Output: 1
// Explanation: None of the intervals overlap, so we can put all of them in one group.
//
// Constraints:
//
//     1 <= intervals.length <= 105
//     intervals[i].length == 2
//     1 <= lefti <= righti <= 106
//
// ---
//
// give best time and space complexity code in rust,give variables usefull name, add comments to explain the code way more clear,also add code to run example case, use below typing
//
// ---
// impl Solution {
//     pub fn min_groups(intervals: Vec<Vec<i32>>) -> i32 {
//
//     }
// }

// %% [markdown]
// Your implementation for the problem of dividing intervals into the minimum number of groups is well-structured! Here’s a revised version of your code that includes comments for clarity, along with code to run example cases. I'll also explain how the code works, focusing on the logic and efficiency.
//
// ```rust
// impl Solution {
//     pub fn min_groups(intervals: Vec<Vec<i32>>) -> i32 {
//         // Step 1: Collect start and end times into two separate vectors
//         let mut starts: Vec<i32> = Vec::with_capacity(intervals.len());
//         let mut ends: Vec<i32> = Vec::with_capacity(intervals.len());
//
//         for interval in &intervals {
//             starts.push(interval[0]); // Collect start times
//             ends.push(interval[1]); // Collect end times
//         }
//
//         // Step 2: Sort the starts and ends
//         starts.sort_unstable(); // Sort start times
//         ends.sort_unstable(); // Sort end times
//
//         let mut total = 0; // To keep track of active intervals
//         let mut max_total = 0; // To record the maximum active intervals at any time
//         let mut start_idx = 0; // Index for traversing start times
//         let mut end_idx = 0; // Index for traversing end times
//
//         // Step 3: Traverse through sorted starts and ends
//         while start_idx < intervals.len() {
//             if starts[start_idx] <= ends[end_idx] {
//                 // A new interval is starting before the current one ends
//                 total += 1; // Increase active interval count
//                 start_idx += 1; // Move to the next start
//                 max_total = max_total.max(total); // Update the maximum if needed
//             } else {
//                 // The current interval has ended
//                 total -= 1; // Decrease active interval count
//                 end_idx += 1; // Move to the next end
//             }
//         }
//
//         max_total // Return the maximum number of overlapping intervals
//     }
// }
//
// fn main() {
//     let intervals1 = vec![vec![5, 10], vec![6, 8], vec![1, 5], vec![2, 3], vec![1, 10]];
//     let result1 = Solution::min_groups(intervals1);
//     println!("Example 1 Result: {}", result1); // Expected output: 3
//
//     let intervals2 = vec![vec![1, 3], vec![5, 6], vec![8, 10], vec![11, 13]];
//     let result2 = Solution::min_groups(intervals2);
//     println!("Example 2 Result: {}", result2); // Expected output: 1
// }
// ```
//
// ### Explanation of the Code:
//
// 1. **Collecting Starts and Ends:**
//
//    - Two vectors, `starts` and `ends`, are populated with the starting and ending points of each interval. This separation helps to process the intervals independently.
//
// 2. **Sorting:**
//
//    - Both vectors are sorted using `sort_unstable()`, which is efficient and sufficient for this use case since we only care about order and not about stability.
//
// 3. **Two-Pointer Technique:**
//
//    - We use two indices, `start_idx` and `end_idx`, to traverse the sorted start and end times.
//    - The main logic compares the current start time with the current end time:
//      - If a new interval starts before the previous one ends, we increment the count of active intervals (`total`).
//      - If the current interval has ended, we decrement the count of active intervals.
//
// 4. **Tracking Maximum Active Intervals:**
//
//    - `max_total` keeps track of the maximum number of overlapping intervals at any point in time.
//
// 5. **Result:**
//    - Finally, the function returns the maximum number of groups needed, which is stored in `max_total`.
//
// ### Time and Space Complexity:
//
// - **Time Complexity:** \(O(n \log n)\) due to the sorting steps, where \(n\) is the number of intervals.
// - **Space Complexity:** \(O(n)\) for storing the start and end vectors.
//
// This approach is efficient and effective for the problem at hand!

// %%
impl Solution {
    pub fn min_groups(intervals: Vec<Vec<i32>>) -> i32 {
        
    }
}
