// %% [markdown]
// 2491. Divide Players Into Teams of Equal Skill
//       Medium
//       Topics
//       Companies
//       Hint
//
// You are given a positive integer array skill of even length n where skill[i] denotes the skill of the ith player. Divide the players into n / 2 teams of size 2 such that the total skill of each team is equal.
//
// The chemistry of a team is equal to the product of the skills of the players on that team.
//
// Return the sum of the chemistry of all the teams, or return -1 if there is no way to divide the players into teams such that the total skill of each team is equal.
//
// Example 1:
//
// Input: skill = [3,2,5,1,3,4]
// Output: 22
// Explanation:
// Divide the players into the following teams: (1, 5), (2, 4), (3, 3), where each team has a total skill of 6.
// The sum of the chemistry of all the teams is: 1 _ 5 + 2 _ 4 + 3 \* 3 = 5 + 8 + 9 = 22.
//
// Example 2:
//
// Input: skill = [3,4]
// Output: 12
// Explanation:
// The two players form a team with a total skill of 7.
// The chemistry of the team is 3 \* 4 = 12.
//
// Example 3:
//
// Input: skill = [1,1,2,3]
// Output: -1
// Explanation:
// There is no way to divide the players into teams such that the total skill of each team is equal.
//
// Constraints:
//
//     2 <= skill.length <= 105
//     skill.length is even.
//     1 <= skill[i] <= 1000
//
// ---
//
// give best time and space complexity code in rust,give variables usefull name, add comments to explain the code way more clear,also add code to run example case, use below typing
//
// ---
//
// impl Solution {
//     pub fn divide_players(skill: Vec<i32>) -> i64 {
//
//     }
// }

// %% [markdown]
// Here's a Rust implementation that solves the problem of dividing players into teams of equal skill. I've included detailed comments to explain the code, as well as code to run example cases.
//
// ```rust
// impl Solution {
//     pub fn divide_players(skill: Vec<i32>) -> i64 {
//         // Get the number of players
//         let n = skill.len();
//
//         // Step 1: Sort the skill array to facilitate pairing
//         let mut skill_sorted = skill.clone();
//         skill_sorted.sort();
//
//         // Step 2: Calculate the total skill for the first team
//         // The team pairs will be (skill_sorted[0], skill_sorted[n-1]), (skill_sorted[1], skill_sorted[n-2]), ...
//         let target_skill = skill_sorted[0] + skill_sorted[n - 1];
//
//         // Initialize the total chemistry
//         let mut total_chemistry: i64 = 0;
//
//         // Step 3: Loop through half of the sorted skill array to form teams
//         for i in 0..(n / 2) {
//             let team_skill = skill_sorted[i] + skill_sorted[n - 1 - i];
//
//             // Check if current pair matches the target skill
//             if team_skill != target_skill {
//                 return -1; // Return -1 if the pairing does not match the required skill
//             }
//
//             // Calculate chemistry for the current team and add to the total
//             total_chemistry += (skill_sorted[i] as i64) * (skill_sorted[n - 1 - i] as i64);
//         }
//
//         // Return the total chemistry of all teams
//         total_chemistry
//     }
// }
//
// fn main() {
//     // Example case 1
//     let skill1 = vec![3, 2, 5, 1, 3, 4];
//     let result1 = Solution::divide_players(skill1);
//     println!("Output for example case 1: {}", result1); // Expected output: 22
//
//     // Example case 2
//     let skill2 = vec![3, 4];
//     let result2 = Solution::divide_players(skill2);
//     println!("Output for example case 2: {}", result2); // Expected output: 12
//
//     // Example case 3
//     let skill3 = vec![1, 1, 2, 3];
//     let result3 = Solution::divide_players(skill3);
//     println!("Output for example case 3: {}", result3); // Expected output: -1
// }
// ```
//
// ### Explanation of the Code:
//
// 1. **Sorting the Skill Array**: We first sort the array to easily access the smallest and largest skills, which helps in pairing players optimally.
//
// 2. **Target Skill Calculation**: We calculate the target skill by adding the smallest skill (`skill_sorted[0]`) and the largest skill (`skill_sorted[n - 1]`). This ensures that each team will have the same total skill.
//
// 3. **Team Formation**: We loop through the first half of the sorted skill array, pairing the ith player from the start with the ith player from the end. If any pair does not match the target skill, we return -1.
//
// 4. **Chemistry Calculation**: If the pairing is valid, we calculate the chemistry for the team (product of skills) and accumulate it.
//
// 5. **Return Value**: Finally, we return the total chemistry after processing all pairs.
//
// ### Time Complexity:
//
// - Sorting the skill array takes \(O(n \log n)\).
// - The pairing and summation take \(O(n)\).
// - Overall, the time complexity is \(O(n \log n)\).
//
// ### Space Complexity:
//
// - The space complexity is \(O(n)\) due to the clone of the skill array for sorting.

// %%
pub struct Solution;

impl Solution {
    pub fn divide_players(skill: Vec<i32>) -> i64 {
        // Get the number of players
        let n = skill.len();
        
        // Step 1: Sort the skill array to facilitate pairing
        let mut skill_sorted = skill.clone();
        skill_sorted.sort();

        // Step 2: Calculate the total skill for the first team
        // The team pairs will be (skill_sorted[0], skill_sorted[n-1]), (skill_sorted[1], skill_sorted[n-2]), ...
        let target_skill = skill_sorted[0] + skill_sorted[n - 1];
        
        // Initialize the total chemistry
        let mut total_chemistry: i64 = 0;

        // Step 3: Loop through half of the sorted skill array to form teams
        for i in 0..(n / 2) {
            let team_skill = skill_sorted[i] + skill_sorted[n - 1 - i];
            
            // Check if current pair matches the target skill
            if team_skill != target_skill {
                return -1; // Return -1 if the pairing does not match the required skill
            }

            // Calculate chemistry for the current team and add to the total
            total_chemistry += (skill_sorted[i] as i64) * (skill_sorted[n - 1 - i] as i64);
        }

        // Return the total chemistry of all teams
        total_chemistry
    }
}

fn main() {
    // Example case 1
    let skill1 = vec![3, 2, 5, 1, 3, 4];
    let result1 = Solution::divide_players(skill1);
    println!("Output for example case 1: {}", result1); // Expected output: 22

    // Example case 2
    let skill2 = vec![3, 4];
    let result2 = Solution::divide_players(skill2);
    println!("Output for example case 2: {}", result2); // Expected output: 12

    // Example case 3
    let skill3 = vec![1, 1, 2, 3];
    let result3 = Solution::divide_players(skill3);
    println!("Output for example case 3: {}", result3); // Expected output: -1
}

main()
// Out:
// Output for example case 1: 22
// Output for example case 2: 12
// Output for example case 3: -1
// ()

// %% [markdown]
// Your Rust implementation is efficient and straightforward! Here's a breakdown of your code, along with a few enhancements to the comments for clarity:
//
// ```rust
// impl Solution {
//     pub fn divide_players(skill: Vec<i32>) -> i64 {
//         // Create a mutable copy of the skill array and sort it in-place
//         let mut skill = skill;
//         skill.sort_unstable(); // Unstable sort is faster; order doesn't matter for equality checks
//
//         // Get the length of the skill array
//         let len = skill.len();
//
//         // Calculate the target sum for each team
//         let sum = skill[0] + skill[len - 1];
//
//         // Initialize the total chemistry
//         let mut ans = 0;
//
//         // Pointers for pairing: one starts at the beginning, the other at the end
//         let mut left = 0;
//         let mut right = len - 1;
//
//         // While pointers do not cross
//         while left < right {
//             // Check if the current pair matches the target sum
//             if skill[left] + skill[right] != sum {
//                 return -1; // If not, return -1 as it's impossible to form equal teams
//             }
//
//             // Calculate the chemistry for the current pair and accumulate
//             ans += i64::from(skill[left] * skill[right]);
//             // Move the pointers towards the center
//             left += 1;
//             right -= 1;
//         }
//
//         // Return the total chemistry of all teams
//         ans
//     }
// }
//
// fn main() {
//     // Example case 1
//     let skill1 = vec![3, 2, 5, 1, 3, 4];
//     let result1 = Solution::divide_players(skill1);
//     println!("Output for example case 1: {}", result1); // Expected output: 22
//
//     // Example case 2
//     let skill2 = vec![3, 4];
//     let result2 = Solution::divide_players(skill2);
//     println!("Output for example case 2: {}", result2); // Expected output: 12
//
//     // Example case 3
//     let skill3 = vec![1, 1, 2, 3];
//     let result3 = Solution::divide_players(skill3);
//     println!("Output for example case 3: {}", result3); // Expected output: -1
// }
// ```
//
// ### Explanation of the Key Parts:
//
// 1. **Sorting**: The `sort_unstable()` method is chosen for performance. It rearranges the array without guaranteeing the order of equal elements, which is sufficient for this problem.
//
// 2. **Pairing Logic**: The two pointers, `left` and `right`, are used to select pairs from the sorted list. This efficiently checks if the sum of the current pair matches the target sum.
//
// 3. **Chemistry Calculation**: The chemistry of each team is computed as the product of the skills of the two players, and results are summed up.
//
// ### Complexity Analysis:
//
// - **Time Complexity**: The sorting step is \(O(n \log n)\), and the pairing step is \(O(n)\). Therefore, the overall complexity is dominated by the sorting step: \(O(n \log n)\).
//
// - **Space Complexity**: The space complexity is \(O(1)\) if we consider the input list as part of the input space, or \(O(n)\) if we consider the temporary storage during sorting. Since we are not using any additional data structures that scale with input size, the space complexity is efficient.
//
// This code is clean and follows good practices for Rust programming, making it easy to understand and maintain. Well done!

// %%
impl Solution {
    pub fn divide_players(skill: Vec<i32>) -> i64 {
        let mut skill = skill;
        skill.sort_unstable();
        let len = skill.len();
        let sum = skill[0] + skill[len - 1];
        let mut ans = 0;
        let mut left = 0;
        let mut right = len - 1;
        while left < right {
            if skill[left] + skill[right] != sum {
                return -1;
            }
            ans += i64::from(skill[left] * skill[right]);
            left += 1;
            right -= 1;
        }
        ans
    }
}
// Out:
// [E0592] Error: duplicate definitions with name `divide_players`
//    ╭─[command_4:1:1]
//    │
//  2 │     pub fn divide_players(skill: Vec<i32>) -> i64 {
//    │     ──────────────────────┬──────────────────────
//    │                           ╰──────────────────────── other definition for `divide_players`
// ───╯
