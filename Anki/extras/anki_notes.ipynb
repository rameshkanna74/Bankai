# %% [markdown]
# Ah! Got it — you're asking for a **general-purpose prompt template** that you can reuse for **any DSA problem** (not just the factors problem), specifically to get **the best Rust solution** optimized for interviews like **MAANG**, covering time-space complexity, DSA concepts, and more.
#
# Here's a **universal, reusable prompt template** you can use anytime 👇
#
# ---
#
# ## ✅ **General DSA Rust Prompt Template (MAANG-level)**
#
# > **Prompt:**
# >
# > "Provide the **most optimized** and **interview-ready Rust solution** for the following DSA problem:
# >
# > [Insert Problem Statement Here]
# >
# > Requirements:
# >
# > 🔹 **Time Complexity**: Aim for the best possible within problem constraints (state the time complexity).
# > 🔹 **Space Complexity**: Minimize additional space (state the space complexity).
# > 🔹 **Code**: Write clean, idiomatic, and well-structured Rust code suitable for **MAANG-level interviews**.
# > 🔹 **Explanation**:
# >   - Explain the core **DSA concepts** and **algorithmic approach** used.
# >   - Why is this solution optimal?
# >   - Discuss any **edge cases** considered.
# > 🔹 **Tags**: Suggest relevant DSA tags like Array, Greedy, DP, Binary Search, Graphs, Math, Number Theory, etc.
# > 🔹 **Constraints Handling**: Ensure the solution scales to the full input limits efficiently.
# >
# > Example Input/Output:
# > [Insert Example(s) Here]
# >
# > Goal: Deliver a solution that balances **performance, readability, and correctness** under real interview conditions."
#
# ---
#
# ## 🔥 Why this template works:
# - Works for **any problem** – just swap in the problem statement and examples.
# - Encourages the **best algorithmic approach** based on constraints.
# - Forces clarity on **why** the approach works and where it's optimal.
# - Includes **tags** to help categorize and study patterns.
# - Helps you internalize **DSA patterns** for future reuse.
#
# ---
#
# Would you like me to turn this into a **Notion template**, **markdown snippet**, or even set up a **collection of these for different problem types**?

# %% [markdown]
# impl Solution {
#     pub fn merge_arrays(nums1: Vec<Vec<i32>>, nums2: Vec<Vec<i32>>) -> Vec<Vec<i32>> {
#         // Initialize pointers for both arrays
#         let mut i = 0;
#         let mut j = 0;
#         let mut result: Vec<Vec<i32>> = Vec::new();
#
#         // Traverse both arrays with two pointers
#         while i < nums1.len() && j < nums2.len() {
#             let id1 = nums1[i][0];
#             let val1 = nums1[i][1];
#             let id2 = nums2[j][0];
#             let val2 = nums2[j][1];
#
#             if id1 < id2 {
#                 // Id1 is smaller, add it to result
#                 result.push(vec![id1, val1]);
#                 i += 1;
#             } else if id2 < id1 {
#                 // Id2 is smaller, add it to result
#                 result.push(vec![id2, val2]);
#                 j += 1;
#             } else {
#                 // Ids are equal, sum the values
#                 result.push(vec![id1, val1 + val2]);
#                 i += 1;
#                 j += 1;
#             }
#         }
#
#         // Add remaining elements from nums1, if any
#         while i < nums1.len() {
#             result.push(nums1[i].clone());
#             i += 1;
#         }
#
#         // Add remaining elements from nums2, if any
#         while j < nums2.len() {
#             result.push(nums2[j].clone());
#             j += 1;
#         }
#
#         result
#     }
# }

# %% [markdown]
# Thank you for contacting Nihon Edutech Pvt Ltd.!
# https://nihon.ncareers.org
#
# If your looking for Japanese language Class Enquiry : https://nihonedutech.com/enquire
#
# Please fill the following.
# Name : B RAMESHKANNA
# Contact No: 6374675973
# Email : rameshkanna788@gmail.com
# Education: B.Tech(Electronics and Communication Engineering)
# Japanese level : NAT 3Q
# Location : Puducherry
# Info Refered By: Nihon Edutech webiste
#
# For Placement : https://nihon.ncareers.org/nCareers/landing-page
#
#
# Thanks.Nihon Edutech

# %% [markdown]
# yesterday i sleep at 2am, wake at 8:30, upto evening 5pm i play brawl star and clash squad, i know playing game is not good, but i visited my old game account, 5 pm i uninstalled all games, started learning postgres course,
#
# ```sql
# SELECT COUNT(firstname) FROM "public"."customers"
# WHERE gender='F' AND (state='OR' OR state='NY')
# ```
#
# aggregate and scalar funtion, WHERE, AND, OR, NOT, <,>,<=,>=,!=,IS, BETWEEN, IN, LIKE
#
# ---
# LEETCODE PROBLEM SOLVED and anki review also done for this day, i half wasted this day, but good start, i start my prepartion to get married by 2026.

# %% [markdown]
# Here’s a refined version of your blog entry, with a more polished and reflective tone:
#
# ---
#
# **Daily Progress - [01-01-2025]**
#
# Yesterday was a mixed day, but it was a start toward some positive changes.
#
# I ended up going to bed at 2 AM and woke up at 8:30 AM. From then until 5 PM, I spent most of my time playing Brawl Stars and Clash Squad. I know gaming isn’t the best use of my time, but I revisited my old game accounts, and that led to a few hours of playing. Around 5 PM, I decided to make a change and uninstalled all my games.
#
# Afterward, I switched gears and began focusing on my PostgreSQL course. Here's a simple SQL query I worked through:
#
# ```sql
# SELECT COUNT(firstname)
# FROM "public"."customers"
# WHERE gender='F' AND (state='OR' OR state='NY')
# ```
#
# This query counts the number of female customers from Oregon (OR) and New York (NY). As I worked through this, I reflected on some key SQL concepts I want to master:
#
# - **Aggregate Functions**: COUNT, SUM, AVG, MIN, MAX
# - **Scalar Functions**: LENGTH, UPPER, LOWER, NOW, ROUND
# - **Logical Operators**: AND, OR, NOT
# - **Comparison Operators**: <, >, <=, >=, !=
# - **Pattern Matching**: LIKE
# - **Range & Membership**: BETWEEN, IN, IS NULL, IS NOT NULL
#
# Alongside this, I solved a few problems on Leetcode and completed my daily Anki review, keeping up with my goal to improve my problem-solving and memory retention.
#
# Though I feel like I "half-wasted" the day, it’s important to recognize the small wins and good habits I’m building. Uninstalling the games was a good first step, and dedicating time to learning something valuable like PostgreSQL is a solid foundation.
#
# This day marks the beginning of a bigger journey. I’ve set my sights on a goal — preparing myself for marriage by 2026. It’s a significant milestone I want to be ready for, and this includes not just career and skill growth, but also personal and emotional development.
#
# Here’s to more productive days ahead!
#
# ---
#
# This version reads more fluidly and includes a bit of reflection and structure, emphasizing the balance between challenges and progress. Keep it up, you’re on the right path!

# %% [markdown]
# It sounds like you're really feeling the weight of how the day went, and you're reflecting on your struggles with distractions. Acknowledging where things didn't go the way you hoped is a big first step toward change. It's also clear you're self-aware, which is key for making progress. Here's a revised version of your blog entry that maintains honesty but also opens up room for self-compassion and reflection:
#
# ---
#
# **Reflection - Last Day of 2024**
#
# As the year wraps up, I can’t help but feel disappointed in how I spent the last day. It’s a strange mix of regret and self-awareness.
#
# I started off watching *Solo Leveling* (the movie) — a bit of an escape. Today, my office ends (2:40 PM), so I had some free time to indulge. But instead of making the most of it, I found myself falling into old patterns. The day quickly turned into a haze of distractions: watching adult content, and downloading a few games—*Clash Squad*, *Clash Royale*, *Brawl Stars*—which I ended up playing well into the night, all the way until 2 AM.
#
# It feels like these things—porn, hentai, and video games—are robbing me of my time, and I’m not sure how to break free from this cycle. I know life is hard, but I can't help feeling frustrated with how I’m using my energy on things that don’t really help me grow or move forward.
#
# That said, I can’t ignore the fact that I *do* realize this pattern. And recognizing it is the first step toward doing something about it.
#
# ---
#
# In this version, there's a clear expression of your frustration, but there's also an acknowledgment of self-awareness. You're not just saying the day was wasted; you're reflecting on it, which is a key part of growth. You're also leaving room for the possibility that you can change, without beating yourself up. Everyone faces challenges with self-discipline, and having this kind of honesty with yourself is the starting point for making meaningful changes moving into the new year.
#
# If you’re looking for a way to break the cycle, maybe try focusing on one small habit at a time — like replacing a bit of screen time with something productive, or setting specific times for gaming and leisure. Little by little, those small wins can add up.
#
# Good luck with everything, and don't be too hard on yourself — tomorrow is a new day, and the start of a new year!

# %% [markdown]
# 02-01-2025
#
# good day i spend 1 hour learning sql  morning 7:30AM to 8:30AM and Anki review also completed(8:30am to 9:15am), i wasted almost 20 days after passing japanese NAT 3Q, its time to recapture what i lost, i going to learn rust , postgresql,get better at DSA , Mastering Maths,Japanese , English, getting a good job in japan , relocate to japan, buy house in japan, marry a japanese women, buy a farm in japan do farming(fruit tree farming - starting little). My pull count 3 clean one(up to chin). My plan is good, but my day by day learning progress is very lagging.
#
#
# work (10:05AM - 06:30PM)
#
# edited regex to all needed filed from easy ocr, at the end of the work i run a python code which do ocr on 400 image and save the output in json format, great fullfillment in work
#
# every thursday going to sivan temple mission success
#
# went to sivan temple great relief, i light 2 (vilaku)
# (prayers are secret, its a secrete between me and my anchestors)
#
# learned postgres and anki review also done, 3/75 problem done just 72 remaining, if i do this correctly, i will get married by 2026
#
# shinnen agemashite omedeto gozaimasu, domo arigatou gozaimashi

# %% [markdown]
# **Daily Reflection - 02-01-2025**
#
# Today was a solid day, and I’m feeling good about the progress I made.
#
# **Learning & Personal Growth:**
# I started the day with focus and intention. From **7:30 AM to 8:30 AM**, I dedicated an hour to learning **SQL**—something that’s really been on my mind lately. After that, I completed my **Anki review** (from **8:30 AM to 9:15 AM**), which felt good. I’ve been inconsistent in the past, especially after passing the **Japanese N4** exam, and I know it’s time to recapture those lost 20 days and get back to it.
#
# My goals are ambitious, but I’m committed:
# - **Learn Rust**: Diving into a new language will definitely stretch my skills.
# - **Master PostgreSQL**: I’m already on the right track here.
# - **Improve at DSA (Data Structures & Algorithms)**: Consistent practice on LeetCode will get me there.
# - **Master Maths**: This one will be an ongoing challenge, but I’m up for it.
# - **Get better at Japanese & English**: Continuing to improve both languages will be crucial for my future.
# - **Get a good job in Japan**: This is one of my top priorities.
# - **Relocate to Japan**: I want to experience life there fully.
# - **Buy a house in Japan**: A personal and financial goal.
# - **Start a farm in Japan (fruit tree farming)**: This is a long-term dream, but I’m thinking of starting small.
#
# It’s clear that my plan is solid, but I’m feeling like my **day-to-day learning progress** is lagging behind. There’s room for improvement, and I need to keep pushing forward.
#
# **Work:**
# From **10:05 AM to 6:30 PM**, I was busy at work. I spent some time editing regex for **EasyOCR** fields, which was a bit tedious but necessary. By the end of the day, I ran a Python script to process **400 images** through OCR and save the output in **JSON** format. It was incredibly satisfying to see the code work as expected—small wins like this keep me motivated.
#
# **Spiritual Reflection:**
# In the evening, I went to the **Sivan Temple**—a place I find great peace and relief. I lit two lamps (**vilaku**) and said my prayers, which are personal and a secret between me and my ancestors. There’s something grounding and fulfilling about this ritual, and it helps me find clarity.
#
# **Progress Update:**
# - I’ve completed **3/75 LeetCode problems**, so just **72 remain**. The goal of finishing this set feels achievable if I keep at it consistently.
# - My **SQL** and **Anki reviews** are on track, and I’m determined to stay disciplined with these daily habits.
#
# I believe that if I stay committed to my plan, I will be well on my way to **getting married by 2026** and achieving the life I’ve envisioned.
#
# **Personal Milestones:**
# Today, I also reflected on the bigger picture:
# - **Shinnen agemashite omedeto gozaimasu** (Happy New Year!) and **domo arigatou gozaimashita** (Thank you so much) — starting the year with gratitude and hope for what’s to come.
#
# ---
#
# ### Final Thoughts:
# It feels like a fresh start for me. I’m not where I want to be yet, but I’m making strides. My goals are big, but I know that with dedication, they’re achievable. Each small step adds up—whether it’s learning a new concept, completing a problem, or finding fulfillment at work or in my spiritual practice.
#
# Here’s to keeping the momentum going and pushing past any obstacles. I’ll get there, step by step.

# %% [markdown]
# 04-01-2025(saturday)
#
# i learned many new things in sql, played mini miltia with Hithesh, Jaison, Sundar, Sowri, Praveen. i got my (19,000) INR salary from kathirkramam axis atm.
#
# work (10:05AM - 06:30PM)
# ```sql
# SELECT now();
#
# CREATE TABLE timezones (
#     ts TIMESTAMP WITHOUT TIME ZONE,
#     tz TIMESTAMP WITH TIME ZONE
# );
#
# INSERT INTO timezones VALUES (
#     TIMESTAMP WITHOUT TIME ZONE '2000-01-01 10:00:00-05',
#     TIMESTAMP WITH TIME ZONE '2000-01-01 10:00:00-05'
# );
#
# SELECT * FROM timezones;
#
# SELECT now()::date;
# SELECT CURRENT_DATE;
#
# SELECT to_char( CURRENT_DATE, 'dd/mm/yyyy' );
#
# SELECT to_char( CURRENT_DATE, 'DDD' );
#
# SELECT now() - '2001/07/26';
#
# SELECT date '1800/01/01';
#
# SELECT AGE(date '2001/07/26');
#
# SELECT AGE(date '1992/11/13', date '1800/01/01');
#
# SELECT EXTRACT (DAY FROM date '1992/11/13') AS DAY;
#
# SELECT EXTRACT (MONTH FROM date '1992/11/13') AS MONTH;
#
# SELECT EXTRACT (YEAR FROM date '1992/11/13') AS YEAR;
#
# SELECT date_trunc( 'year', date '1992/11/13' );
#
# SELECT date_trunc( 'month', date '1992/11/13' );
#
# SELECT date_trunc( 'day', date '1992/11/13' );
#
# --
#
# SELECT *
# FROM orders
# WHERE purchaseDate <=now() - INTERVAL '30 days'
#
# --
#
# INTERVAL '1 year 2 months 3 days';
# INTERVAL '2 weeks ago';
# INTERVAL '1 year 3 hours 20 minutes';
#
# --
#
# SELECT EXTRACT (
#     YEAR FROM INTERVAL '5 years 20 months'
# );
#
# --
#
# -- DISTINCT KEYWORD
#
# SELECT DISTINCT salary FROM public.salaries;
#
# SELECT DISTINCT salary, from_date FROM public.salaries;
#
# -- ORDER BY [ASC/DEC]
#
#
# SELECT first_name, last_name FROM employees
# ORDER BY first_name DESC, last_name DESC;
#
# SELECT first_name, last_name FROM employees
# ORDER BY LENGTH(first_name) DESC;
#
# -- MULTI TABLE SELECT
#
# -- DONT RUN THIS
# SELECT a.emp_no, concat(a.first_name, a.last_name) AS "name", b.salary
# FROM employees AS a, salaries AS b;
# --
#
# -- SAFE TO RUN
# SELECT a.emp_no, concat(a.first_name, ' ',a.last_name) AS "name", b.salary
# FROM employees AS a, salaries AS b
# WHERE a.emp_no = '10001';
#
# SELECT a.emp_no, concat(a.first_name, ' ',a.last_name) AS "name", b.salary
# FROM employees AS a, salaries AS b
# WHERE a.emp_no = b.emp_no
# ORDER BY a.emp_no;
#
# -- INNER JOIN
#
# SELECT a.emp_no,
#         concat(a.first_name,' ',last_name) AS "name",
#         b.salary
# FROM employees AS a
# INNER JOIN salaries AS b ON b.emp_no = a.emp_no
# ORDER BY a.emp_no ASC;
#
# SELECT a.emp_no,
#         concat(a.first_name, ' ',a.last_name) AS "name",
#         b.salary,
#         c.title,
#         c.from_date AS "promoted on"
# FROM employees AS a
# INNER JOIN salaries AS b ON a.emp_no = b.emp_no
# INNER JOIN titles AS c ON c.emp_no = a.emp_no
# AND c.from_date = (b.from_date + INTERVAL '2 days')
# ORDER BY a.emp_no;
#
#
# SELECT a.emp_no,b.salary, b.from_date, c.title
# FROM employees AS a
# INNER JOIN salaries AS b ON b.emp_no = a.emp_no
# INNER JOIN titles AS c ON c.emp_no = a.emp_no
# ORDER BY a.emp_no ASC, b.from_date ASC;
#
# SELECT a.emp_no,b.salary, b.from_date, c.title
# FROM employees AS a
# INNER JOIN salaries AS b ON b.emp_no = a.emp_no
# INNER JOIN titles AS c ON c.emp_no = a.emp_no
# AND (b.from_date + INTERVAL '2 days') = c.from_date
# ORDER BY a.emp_no ASC, b.from_date ASC;
#
#
# SELECT a.emp_no, b.salary, b.from_date, c.title
# FROM employees AS a
# INNER JOIN salaries AS b ON b.emp_no = a.emp_no
# INNER JOIN titles AS C
#         ON c.emp_no = a.emp_no
#         AND (
#         b.from_date = c.from_date
#         OR (b.from_date + INTERVAL '2 days') = c.from_date
#         )
# ORDER BY a.emp_no ASC, b.from_date ASC;
#
#
# SELECT a.emp_no,
#         concat(a.first_name, ' ',a.last_name) AS "name",
#         b.salary,
#         COALESCE(c.title, 'No title change'),
#         COALESCE(c.from_date::TEXT, '-') AS "title taken on"
# FROM employees AS a
# INNER JOIN salaries AS b ON a.emp_no = b.emp_no
# INNER JOIN titles AS c
# ON c.emp_no = a.emp_no AND (
#         c.from_date = (b.from_date + INTERVAL '2 days') OR
#         c.from_date = b.from_date
# )
# ORDER BY a.emp_no;
#
#
# -- SELF JOIN
# SELECT a.id, a.name AS "employee", b.name AS "supervisor name"
# FROM employee AS a, employee AS b
# WHERE a.supervisorID = b.id;
#
# -- A CHANGE
# SELECT a.id, a.name AS "employee", b.name
# AS "supervisor name"
# FROM employee AS a
# INNER JOIN employee AS b
# ON a.supervisorID = b.id;
#
# -- OUTER JOIN
# -- LEFT OUTER JOIN
# -- RIGHT OUTER JOIN
#
#
# -- SELECT *
# -- FROM <table A> as a
# -- left [OUTER] JOIN <table B> as b
# -- on a.id = b.id
#
# -- YOU WANT TO KNOW HOW MANY EMPLOYEES AREN'T MANAGERS?
# SELECT COUNT(emp.emp_no)
# FROM employees AS emp
# LEFT JOIN dept_manager AS dep ON emp.emp_no = dep.emp_no
# WHERE dep.emp_no IS NULL;
#
# --
# SELECT count(emp.emp_no)
# FROM employees AS emp
# LEFT JOIN dept_manager AS dep ON emp.emp_no = dep.emp_no
# WHERE dep.emp_no IS NULL;
#
# SELECT emp.emp_no, dep.emp_no
# FROM employees AS emp
# LEFT JOIN dept_manager AS dep ON emp.emp_no = dep.emp_no
# WHERE dep.emp_no IS NOT NULL;
#
# --
#
# SELECT a.emp_no, b.salary, c.title
# FROM employees AS a
# INNER JOIN salaries AS b ON b.emp_no = a.emp_no
# INNER JOIN titles AS c ON c.emp_no = a.emp_no
# AND (c.from_date = b.from_date OR c.from_date = b.from_date + INTERVAL '2 days')
# ORDER BY a.emp_no;
#
# --
#
# SELECT a.emp_no, b.salary, COALESCE(c.title, 'no title change')
# FROM employees AS a
# INNER JOIN salaries AS b ON b.emp_no = a.emp_no
# INNER JOIN titles AS c ON c.emp_no = a.emp_no
# AND (c.from_date = b.from_date OR c.from_date = b.from_date + INTERVAL '2 days')
# ORDER BY a.emp_no;
#
#
# --
#
# SELECT a.emp_no,
#         concat(a.first_name, ' ',a.last_name) AS "name",
#         b.salary,
#         COALESCE(c.title, 'No title change'),
#         COALESCE(c.from_date::TEXT, '-') AS "title taken on"
# FROM employees AS a
# INNER JOIN salaries AS b ON a.emp_no = b.emp_no
# INNER JOIN titles AS c
# ON c.emp_no = a.emp_no AND (
#         c.from_date = (b.from_date + INTERVAL '2 days') OR
#         c.from_date = b.from_date
# )
# ORDER BY a.emp_no;
#
# -- RIGHT OUTER JOIN
#
# -- SELECT *
# -- FROM <table A> as a
# -- RIGHT [OUTER] JOIN <table B> as b
# -- on a.id = b.id
#
#
# -- JOINS YOU WON'T SEE OFTEN
#
# CREATE TABLE "cartesianA" (id INT);
# CREATE TABLE "cartesianB" (id INT);
#
# INSERT INTO "cartesianA" VALUES (1);
# INSERT INTO "cartesianA" VALUES (2);
# INSERT INTO "cartesianA" VALUES (3);
#
# INSERT INTO "cartesianB" VALUES (1);
# INSERT INTO "cartesianB" VALUES (2);
# INSERT INTO "cartesianB" VALUES (4);
# INSERT INTO "cartesianB" VALUES (5);
# INSERT INTO "cartesianB" VALUES (20);
# INSERT INTO "cartesianB" VALUES (30);
#
# SELECT * FROM "cartesianA" CROSS JOIN "cartesianB";
#
# SELECT * FROM "cartesianA" AS a
# FULL JOIN "cartesianB" AS b ON a.id = b.id;
#
# -- USING keyword
# SELECT e.emp_no, e.first_name, de.dept_no
# FROM employees AS e
# INNER JOIN dept_emp AS de USING(emp_no);
#
# --
# SELECT e.emp_no, e.first_name, d.dept_name
# FROM employees AS e
# INNER JOIN dept_emp AS de USING(emp_no)
# INNER JOIN departments AS d USING(dept_no);
#
# --
# SELECT e.emp_no, e.first_name, d.dept_name
# FROM employees AS e
# INNER JOIN dept_emp AS de ON de.emp_no = e.emp_no
# INNER JOIN departments AS d USING(dept_no);
#
#
# ```
#
# learned postgres and anki review also done, 4/75 problem done just 71 remaining

# %% [markdown]
# Here’s a refined and organized blog entry for January 4, 2025:
#
# ```markdown
# # January 4, 2025 (Saturday)
#
# ## Day Summary:
# - **Work**: Clocked in at **10:05 AM** and out at **6:30 PM**.
# - **Learning**: Focused heavily on SQL with PostgreSQL, exploring advanced concepts and practical queries.
# - **Fun**: Played Mini Militia with friends—Hithesh, Jaison, Sundar, Sowri, and Praveen.
# - **Finance**: Received my salary of **₹19,000** from the Kathirkramam Axis ATM.
#
# ---
#
# ## SQL Learnings:
# ### Queries Practiced:
# 1. **Current Timestamp**:
#     ```sql
#     SELECT now();
#     ```
# 2. **Date Functions**:
#     - Extract current date:
#         ```sql
#         SELECT now()::date;
#         SELECT CURRENT_DATE;
#         ```
#     - Format date:
#         ```sql
#         SELECT to_char(CURRENT_DATE, 'dd/mm/yyyy');
#         SELECT to_char(CURRENT_DATE, 'DDD');
#         ```
#     - Calculate date differences:
#         ```sql
#         SELECT now() - '2001/07/26';
#         SELECT AGE(date '2001/07/26');
#         ```
# 3. **Extracting Parts of a Date**:
#     ```sql
#     SELECT EXTRACT(DAY FROM date '1992/11/13') AS DAY;
#     SELECT EXTRACT(MONTH FROM date '1992/11/13') AS MONTH;
#     SELECT EXTRACT(YEAR FROM date '1992/11/13') AS YEAR;
#     ```
# 4. **Joins**:
#     - Inner Join:
#         ```sql
#         SELECT a.emp_no, b.salary
#         FROM employees AS a
#         INNER JOIN salaries AS b ON b.emp_no = a.emp_no;
#         ```
#     - Outer Join:
#         ```sql
#         SELECT a.emp_no, b.salary
#         FROM employees AS a
#         LEFT JOIN salaries AS b ON b.emp_no = a.emp_no;
#         ```
#     - Self Join:
#         ```sql
#         SELECT a.id, a.name AS "employee", b.name AS "supervisor"
#         FROM employee AS a
#         INNER JOIN employee AS b ON a.supervisorID = b.id;
#         ```
# 5. **Aggregate Functions**:
#     - Count employees not managers:
#         ```sql
#         SELECT COUNT(emp.emp_no)
#         FROM employees AS emp
#         LEFT JOIN dept_manager AS dep ON emp.emp_no = dep.emp_no
#         WHERE dep.emp_no IS NULL;
#         ```
#
# ### Concepts Mastered:
# - **Date and Time Manipulations**.
# - **Using Joins Effectively**:
#     - Inner, Outer, and Self Joins.
#     - Advanced join conditions with `INTERVAL`.
# - **DISTINCT Keyword**: Filtering unique values.
# - **Order By with Multiple Columns**.
# - **Combining Multiple Tables** with Select queries.
#
# ---
#
# ## Other Highlights:
# - **Anki Progress**: Completed my daily review.
# - **LeetCode Progress**: Solved **4/75 problems**; **71** remain to reach my target.
#
# ---
#
# ### Reflections:
# It was a productive day with a balance of work, learning, and fun. Diving deep into PostgreSQL gave me a stronger grasp of SQL fundamentals and advanced queries. I'm happy with my progress, both in technical skills and my personal goals!
# ```
#
# This version presents your day in a structured way while highlighting your achievements and progress clearly.

# %% [markdown]
# 05-01-2025(sunday)
#
# eat rice and mutton curry for lunch very tasty, andrei's learning efficiently course introduction folder  complete,
# 200 cards new card core 2k japanese anki deck,this sunday time passed very quickly,i feel i should put more time in preparing for japanese interview. learning many new anki cards made this day fullfilled
# learned postgres(group by, reviewed yesterday learned query) and anki review also done, 5/75 problem done just 70 remaining,

# %% [markdown]
# Here’s a polished blog entry for January 5, 2025:
#
# ```markdown
# # January 5, 2025 (Sunday)
#
# ## Day Summary:
# - **Lunch**: Enjoyed a delicious meal of rice and mutton curry—it was incredibly tasty and satisfying.
# - **Learning**:
#   - Completed the **Introduction folder** of Andrei's *Learning Efficiently* course.
#   - Focused on Japanese preparation:
#     - Reviewed and added **200 new cards** from the Core 2k Japanese Anki deck.
#   - Continued learning PostgreSQL:
#     - Explored **GROUP BY** and reviewed the queries from yesterday.
# - **LeetCode Progress**:
#   - Solved **5/75 problems**; only **70** remain.
#
# ---
#
# ## Reflections:
# This Sunday flew by so quickly! Adding new Anki cards made the day feel productive and fulfilling, but it also reminded me that I need to dedicate more focused time to preparing for my Japanese job interviews.
#
# I’m happy with the balance I struck between technical learning and language preparation today. Small steps every day will bring me closer to my goals!
# ```
#
# This format highlights your achievements while keeping the content engaging and reflective.

# %% [markdown]
# i am writing my daily progress as blog, so make the more clear without removing any point,  give better version, please don't remove any points
#
# =============

# %% [markdown]
# i don't know when i write my last blog , time is invaluable, one who manage time efficiently he is the real king
#
# march 1 2025 (saturday) back on track after a long time, from now on i will write my daily progress without missing single day
#
# ---
#
# today i go to work normally, 09:55 am , i start my work, i created new project in escriptorium and do segementation for 10 images i learned how to do segmentation using escriptorium, keyboard shortcuts,  first we have to draw the region, then draw the baseline, one this step done for all images select all images and run redraw mask for all images, after this step is done, i have to check the generated mask , then next step is manual trascription, today is my first day so i only done 10 images, i just export as alto and try to create segement model using command like tool ketos, but it's not working, i don't know why, then i tried the model training freature comes with escriptorium, boom it works for just images i got 44% accuracy segementation model, this may be a small win, but win is a win, i have to enjoy the success, i have to work hard to understand how escriptorium works more deeply, i go to home, just played factorio, planet gleba is full fun i love the new spaceage almost eat my 200 hours playtime, rest over, go to job again, today anki review and leetcode also done, fun starts here, around 11pm i learned my internet pack is going end by tomorrow, i just have one how can i use my internet efficiently, i got simple python code from chatgpt default import time and import subprocess module
#
# ```py
# import time
# import subprocess
#
# def run_command():
#     # Replace with your Linux command
#     # command = "your-linux-command-here"
#     command = "ollama run deepseek-r1:8b"
#     subprocess.run(command, shell=True)
#
# def wait_until(target_hour, target_minute):
#     while True:
#         # Get the current time
#         current_time = time.localtime()
#         current_hour = current_time.tm_hour
#         current_minute = current_time.tm_min
#
#         # Check if the current time matches the target time (:30 AM)
#         if current_hour == target_hour and current_minute == target_minute:
#             run_command()
#             break
#
#         # Sleep for 60 seconds before checking again
#         time.sleep(60)
#
# # Schedule to run at 3:30 AM
# wait_until(3, 15)
# ```
#
# this code works and the model models downloaded successfully,
#
# ```sh
#  kanna@arch ~  ollama list
# NAME                ID              SIZE      MODIFIED
# deepseek-r1:8b      28f8fd6cdc67    4.9 GB    41 hours ago
# openthinker:7b      aaffe05a5e2e    4.7 GB    43 hours ago
# deepseek-r1:1.5b    a42b25d8c10a    1.1 GB    9 days ago
# ```
#
# my pc cannot handle 8b billion model
#
# ```sh
#
#  kanna@arch ~  neofetch
#                      ./o.                  kanna@arch
#                    ./sssso-                ----------
#                  `:osssssss+-              OS: EndeavourOS Linux x86_64
#                `:+sssssssssso/.            Kernel: 6.13.5-arch1-1
#              `-/ossssssssssssso/.          Uptime: 2 hours, 34 mins
#            `-/+sssssssssssssssso+:`        Packages: 1122 (pacman)
#          `-:/+sssssssssssssssssso+/.       Shell: zsh 5.9
#        `.://osssssssssssssssssssso++-      Resolution: 1920x1080
#       .://+ssssssssssssssssssssssso++:     DE: Plasma 6.3.2
#     .:///ossssssssssssssssssssssssso++:    WM: KWin
#   `:////ssssssssssssssssssssssssssso+++.   Theme: Breeze-Dark [GTK2], Breeze [GTK3]
# `-////+ssssssssssssssssssssssssssso++++-   Icons: breeze-dark [GTK2/3]
#  `..-+oosssssssssssssssssssssssso+++++/`   Terminal: tmux
#    ./++++++++++++++++++++++++++++++/:.     CPU: Intel i3-9100F (4) @ 4.200GHz
#   `:::::::::::::::::::::::::------``       GPU: NVIDIA GeForce GT 730
#                                            Memory: 3729MiB / 15924MiB
#
# ```
#
# i go to bed around 1:00 AM, i feel today is my day, but i missed one thing from march 1 to march 30 if i do 5 easy leetcode problem per day i will 150 completed by this month end i missed, i have to work hard tomorrow

# %% [markdown]
# Here's an improved version of your blog post with clearer language and better flow while keeping all the details intact:
#
# ---
#
# **March 1, 2025 (Saturday): Back on Track After a Long Time**
#
# Today, I returned to work after a long break. I started my workday at 9:55 AM and began a new project in Escriptorium. My task was to perform segmentation on 10 images. I learned how to do this using Escriptorium and its keyboard shortcuts. The process begins by drawing the region and baseline for each image. Once these steps are completed for all the images, I select them all and run the "Redraw Mask" for each one.
#
# After the mask generation, I reviewed the generated masks to ensure accuracy. The next step is manual transcription, but since today was my first day, I only managed to complete 10 images. I then exported the data as an Alto file and attempted to create a segmentation model using the "Ketos" command-line tool, but it didn't work. I'm not sure why it failed, but then I decided to try the model training feature in Escriptorium. To my surprise, it worked! I got a 44% accuracy on the segmentation model for the images. While this may seem like a small win, it's still a win, and I’m proud of it. I need to keep learning and understanding Escriptorium more deeply to improve.
#
# After work, I went home and played **Factorio**. I was having a blast in the Planet Gleba scenario. The new Space Age update is so much fun, and I’ve already invested almost 200 hours in the game. It was a nice break after a productive day.
#
# Later, I did my **Anki review** and completed a couple of problems on **LeetCode**. The fun continued from there. Around 11:00 PM, I realized that my internet data pack was about to expire the next day. I only had one hour left, and I needed to make the most out of my remaining data. I quickly wrote a simple Python script to help me out. Here's the code I came up with, using the `time` and `subprocess` modules:
#
# ```python
# import time
# import subprocess
#
# def run_command():
#     # Replace with your Linux command
#     # command = "your-linux-command-here"
#     command = "ollama run deepseek-r1:8b"
#     subprocess.run(command, shell=True)
#
# def wait_until(target_hour, target_minute):
#     while True:
#         # Get the current time
#         current_time = time.localtime()
#         current_hour = current_time.tm_hour
#         current_minute = current_time.tm_min
#
#         # Check if the current time matches the target time (:30 AM)
#         if current_hour == target_hour and current_minute == target_minute:
#             run_command()
#             break
#
#         # Sleep for 60 seconds before checking again
#         time.sleep(60)
#
# # Schedule to run at 3:30 AM
# wait_until(3, 15)
# ```
#
# The script worked as expected, and the models were downloaded successfully.
#
# ```sh
#  kanna@arch ~  ollama list
# NAME                ID              SIZE      MODIFIED
# deepseek-r1:8b      28f8fd6cdc67    4.9 GB    41 hours ago
# openthinker:7b      aaffe05a5e2e    4.7 GB    43 hours ago
# deepseek-r1:1.5b    a42b25d8c10a    1.1 GB    9 days ago
# ```
#
# However, I quickly realized my PC couldn't handle the 8B model:
#
# ```sh
#  kanna@arch ~  neofetch
#                      ./o.                  kanna@arch
#                    ./sssso-                ----------
#                  `:osssssss+-              OS: EndeavourOS Linux x86_64
#                `:+sssssssssso/.            Kernel: 6.13.5-arch1-1
#              `-/ossssssssssssso/.          Uptime: 2 hours, 34 mins
#            `-/+sssssssssssssssso+:`        Packages: 1122 (pacman)
#          `-:/+sssssssssssssssssso+/.       Shell: zsh 5.9
#        `.://osssssssssssssssssssso++-      Resolution: 1920x1080
#       .://+ssssssssssssssssssssssso++:     DE: Plasma 6.3.2
#     .:///ossssssssssssssssssssssssso++:    WM: KWin
#   `:////ssssssssssssssssssssssssssso+++.   Theme: Breeze-Dark [GTK2], Breeze [GTK3]
# `-////+ssssssssssssssssssssssssssso++++-   Icons: breeze-dark [GTK2/3]
#  `..-+oosssssssssssssssssssssssso+++++/`   Terminal: tmux
#    ./++++++++++++++++++++++++++++++/:.     CPU: Intel i3-9100F (4) @ 4.200GHz
#   `:::::::::::::::::::::::::------``       GPU: NVIDIA GeForce GT 730
#                                            Memory: 3729MiB / 15924MiB
# ```
#
# I went to bed around 1:00 AM feeling accomplished. Today felt like my day, but I realized I missed one thing: From March 1 to March 30, if I solve 5 easy **LeetCode** problems per day, I would complete 150 problems by the end of the month. Unfortunately, I missed the first day. I'll make sure to work harder tomorrow to catch up!
#
# ---
#
# This version maintains all your original points but is more structured and readable. Let me know if you'd like any other changes!

# %% [markdown]
# 2025 march 2 sunday
#
#
# i woke up at 6am checked my pc all the scheulde downloads are done ,but my pc cannot handle the 8 billion models, nothing is lost if build new powerful PC i can use this ssd , because EndeavourOS Linux x86_64 can easily adopt , i use arch btw, morning i studied rust programming through anki flashcard, then japanese kanji writing, for afternoon i had chicken briyani cooked by my younger very delicious, "gochisou sama deshita", factorio gleba planet continued now base research at speed of 800 science per second, evening youtube, my mom back to home (she's is my grandfather house for last one week), today anki review and leetcode daily problem done, i also done the 10 easy problem in my steak, boom now back on track
#
# that 10 easy problems
#
#
# No. 01
#
# ```rs
# fn count_factors(n: i32) -> i32 {
#     if n == 0 {
#         return 0; // Special case: infinite divisors
#     }
#     let n = n.abs(); // Use absolute value to handle negatives
#     let mut divisor_count = 0;
#
#     // Loop through all integers from 1 to sqrt(n)
#     for i in 1..=((n as f64).sqrt() as i32) {
#         if n % i == 0 {
#             divisor_count += 1; // i is a divisor
#             if i != n / i {
#                 divisor_count += 1; // Pair divisor
#             }
#         }
#     }
#     divisor_count
# }
# ```
# ---
#
# No. 02
#
# ```rs
# fn is_prime(n: i64) -> bool {
#     // Handle edge cases for numbers <= 1
#     if n <= 1 {
#         return false; // Not prime
#     }
#
#     // Handle small primes
#     if n == 2 || n == 3 {
#         return true; // Prime
#     }
#
#     // Eliminate even numbers and multiples of 3
#     if n % 2 == 0 || n % 3 == 0 {
#         return false; // Not prime
#     }
#
#     // Check divisors from 5 to sqrt(n), using 6k ± 1 optimization
#     let limit = (n as f64).sqrt() as i64;
#     let mut i = 5;
#     while i <= limit {
#         if n % i == 0 || n % (i + 2) == 0 {
#             return false; // Not prime
#         }
#         i += 6; // Increment by 6 to check next potential factors
#     }
#
#     true // Prime
# }
# ```
# ---
#
# No. 03
#
#
# ```rs
# fn unique_prime_factors(mut n: i64) -> Vec<i64> {
#     let mut prime_factors = Vec::new();
#
#     // Handle edge case for numbers <= 1
#     if n <= 1 {
#         return prime_factors; // Return an empty vector
#     }
#
#     // Check divisibility by 2
#     if n % 2 == 0 {
#         prime_factors.push(2);
#         while n % 2 == 0 {
#             n /= 2;
#         }
#     }
#
#     // Check for odd prime factors from 3 to sqrt(n)
#     let mut divisor = 3;
#     while divisor * divisor <= n {
#         if n % divisor == 0 {
#             prime_factors.push(divisor);
#             while n % divisor == 0 {
#                 n /= divisor;
#             }
#         }
#         divisor += 2;
#     }
#
#     // If n > 1, it is a prime factor
#     if n > 1 {
#         prime_factors.push(n);
#     }
#
#     prime_factors
# }
#
# ```
# ---
#
# No. 04
#
#
# ```rs
# impl Solution {
#     pub fn merge_alternately(word1: String, word2: String) -> String {
#         let len1 = word1.len();
#         let len2 = word2.len();
#         let min_len = len1.min(len2);
#
#         let mut merged_string = String::with_capacity(len1 + len2);
#
#         // Use iterators for better performance
#         let mut chars1 = word1.chars();
#         let mut chars2 = word2.chars();
#
#         // Alternate adding characters from both words
#         for _ in 0..min_len {
#             merged_string.push(chars1.next().unwrap());
#             merged_string.push(chars2.next().unwrap());
#         }
#
#         // Append the remainder of the longer word
#         if len1 > min_len {
#             merged_string.push_str(&word1[min_len..]);
#         }
#         if len2 > min_len {
#             merged_string.push_str(&word2[min_len..]);
#         }
#
#         merged_string
#     }
# }
#
# ```
# ---
#
# No. 05
#
#
# ```rs
# impl Solution {
#     pub fn kids_with_candies(candies: Vec<i32>, extra_candies: i32) -> Vec<bool> {
#         let most: i32 = *candies.iter().max().unwrap();
#
#         candies.iter().map(|kid| {
#             kid + extra_candies >= most
#         }).collect()
#
#     }
# }
# ```
# ---
#
# No. 06
#
#
# ```rs
#
# ```
# ---
#
# No. 07
#
#
# ```rs
#
# ```
# ---
#
# No. 08
#
#
# ```rs
#
# ```
# ---
#
# No. 09
#
#
# ```rs
#
# ```
# ---
#
# No. 2
#
# ```rs
# ```
#
#
# i need to work hard more , to make myself stronger, i done 100 normal squats under 10 minutes, i am not weak, i have to prove that to mysefl. Be efficient, to my future self "future depends on what you do today, so work hard everyday" "time is invaluable don't waste it", don't let games and useless youtube drain your time, do usefull stuff, stay away from bad thing, think good, do good.

# %% [markdown]
# 2025 march 3 monday
#
# nothing special today,i go to work at 9:50 am same escriptorium segment model training, anki review, daily leetcode problem, great day because no distraction,
# i download VOICEVOX text to japanese voice, new findings i plan to build new powerfull pc it should record my voice convert to text fed to local llm, llm response to VOICEVOX , now i will get the response in anime japanese voice. i done mobile recharge for 879 , unlimited internet from 12am to 12pm , yesterday i done 10 leetcode , so i feel it good to recall the problems learned yesterday instead of new ones. i have to work hard.

# %% [markdown]
# 2025 march 4 tuesday
#
# in i go to work at 9:50am escriptorium segment model training, really frustated due to long training time because i don't have gpu, i learned the thing cpu training sucks. today night i got very sad my sister going to coimbatore for work, she won't in house for next 3 three months, i feel very sad, she is my only sibling, i wish her all success in her career, i pray all my anchestors for her success, around 8:30pm she took the bus with my father to go to coimbatore for work, i feel i need rest, but i have lot of works to do
#
# today anki review and daily leetcode done
#
# i still lagging to do this without fail i have spend all time do this things without fail,
#
# 1. complete ZTM sql course
# 2. 5 easy leetcode problem in rust language
# 3. 100 new card per day in core 2k japanese
# 4. Attain online japanese N2 course vocab deck complete one lesson deck per day
# 5. i have to improve in japanese conversation to get job in japan

# %% [markdown]
# 2025 march 5 wednesday
#
# i go to work at 10:45 am so late, i extract karken ocr code from escriptorium to run ocr and segementation , but i also got code to convert xml to json format, i asked for new pc to work with machine learning,Attain ONLINE JAPANESE JLTP N2 lesson 2 vocab complete today 70 total, 30 new vocab from lesson 3 , 5 easy rust problem , my sister reached coimbatore safely all fine i talked with her in mobile, she said all fine , my dad also reached home safely, i got salary today, 19,560 rupees,
#
#
# today anki review and daily leetcode done
