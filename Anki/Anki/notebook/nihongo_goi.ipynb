# %%
import pandas as pd

# %%
# vocab_data = pd.read_csv("Takoboto.20240322-153911.csv")
vocab_data = pd.read_csv("24_sep_11_vocab.csv")

# %%
df = vocab_data
df[df["List"] == "History"]
# Out:
#        List       ID          Time                 Word  \
# 1   History  1590240  6.386159e+17  貸出, かしだし, 貸し出し, 貸出し
# 2   History  1512180  6.386159e+17            返却, へんきゃく
# 3   History  1414170  6.386159e+17        大人, おとな, だいにん
# 4   History  1315060  6.386159e+17              児童, じどう
# 5   History  1477390  6.386159e+17             発行, はっこう
# ..      ...      ...           ...                  ...
# 77  History  1172400  6.386024e+17         嘘, うそ, 噓, ウソ
# 78  History  1446760  6.386024e+17             島, しま, 嶋
# 79  History  1272820  6.386024e+17              光る, ひかる
# 80  History  1407980  6.386024e+17              多分, たぶん
# 81  History  1001640  6.386024e+17  お陰, おかげ, お蔭, 御陰, 御蔭
#
#                                           Translation
# 1                                    lending, loaning
# 2                      return of something, repayment
# 3                     adult, grown-up, முதிர் அகவையர்
# 4                                  children, juvenile
# 5   publication (of a newspaper, magazine, book, e...
# ..                                                ...
# 77  lie, fib, falsehood, untruth, பொய், தவரு, , mi...
# 78  island, தீவு, , one's territory (e.g. of a sex...
# 79                 to shine, to glitter, to be bright
# 80   perhaps, probably, , generous, many, much, great
# 81  grace (of God), benevolence (of Buddha), bless...
#
# [81 rows x 5 columns]

# %%
df = vocab_data
df_filtered = df[df["List"] != "History"]
df_filtered
# Out:
#            List       ID          Time             Word  \
# 0     Favorites        -           NaN       Empty list
# 82          aaa        -           NaN       Empty list
# 83          kka        -           NaN       Empty list
# 84     N3\N3_01  1211630  6.386158e+17        完了, かんりょう
# 85     N3\N3_01  1598350  6.386158e+17    手続き, てつづき, 手続
# ...         ...      ...           ...              ...
# 2001      zzzzz  1324710  6.385233e+17          弱気, よわき
# 2002      zzzzz  1346190  6.385233e+17          勝手, かって
# 2003      zzzzz  1282100  6.385233e+17         行動, こうどう
# 2004      zzzzz  1436900  6.385233e+17            泥, どろ
# 2005      zzzzz  1565750  6.385233e+17  埃, ほこり, ホコリ, あい
#
#                                             Translation
# 0                                                   NaN
# 82                                                  NaN
# 83                                                  NaN
# 84    completion, conclusion, , perfect (tense, form...
# 85         procedure, process, proceedings, formalities
# ...                                                 ...
# 2001  timid, weak-kneed, fainthearted, , bearish (e....
# 2002  one's own convenience, one's way, selfishness,...
# 2003  action, conduct, behaviour, behavior, mobiliza...
# 2004  mud, slush, (wet) dirt, mire, சறடு, , thief, சேறு
# 2005                          dust, , one ten-billionth
#
# [1925 rows x 5 columns]

# %%
vocab_data = df_filtered
list_data = vocab_data.groupby("List")

# %%
list_data

# %%
(vocab_data[vocab_data["List"].str.contains("N3_07")])
# Out:
#          List       ID          Time                   Word  \
# 474  N3\N3_07  1419570  6.384805e+17          断る, ことわる, 断わる
# 475  N3\N3_07  1452500  6.384806e+17                同時, どうじ
# 476  N3\N3_07  1046340  6.384806e+17            グラウンド, グランド
# 477  N3\N3_07  1331020  6.384806e+17                 周, しゅう
# 478  N3\N3_07  1551710  6.384806e+17                立場, たちば
# ..        ...      ...           ...                    ...
# 530  N3\N3_07  1219910  6.385233e+17            希望, きぼう, 冀望
# 531  N3\N3_07  1006570  6.385233e+17                    せめて
# 532  N3\N3_07  1606000  6.385233e+17  夜更かし, よふかし, 夜更し, 夜ふかし
# 533  N3\N3_07  1372800  6.385233e+17      随分, ずいぶん, ずい分, 隨分
# 534  N3\N3_07  1557950  6.385233e+17             暦, こよみ, れき
#
#                                            Translation
# 474  to refuse, to reject, to dismiss, to turn down...
# 475  simultaneous, concurrent, same time, synchrono...
# 476      field, sports ground, sports oval, playground
# 477  counter for laps or circuits, சவு அரசமரபு, , p...
# 478  position, situation, நிலை, , viewpoint, standp...
# ..                                                 ...
# 530  hope, wish, aspiration, நம்பிக்கை, , (bright) ...
# 531                     at least, at most, (even) just
# 532  staying up late, keeping late hours, sitting u...
# 533  very, extremely, surprisingly, considerably, a...
# 534                      calendar, almanac, நாட்காட்டி
#
# [61 rows x 5 columns]

# %%
vocab_data[vocab_data["List"].str.contains("N3_01")]["Word"]
# Out:
# 63                            完了, かんりょう
# 64                        手続き, てつづき, 手続
# 65                            返却, へんきゃく
# 66                             発行, はっこう
# 67                  貸出, かしだし, 貸し出し, 貸出し
# 68                          再発行, さいはっこう
# 69                           可能性, かのうせい
# 70                       状況, じょうきょう, 情況
# 71                           可笑しい, おかしい
# 72                             開館, かいかん
# 73                             閉館, へいかん
# 74                            休館, きゅうかん
# 75                          休館日, きゅうかんび
# 76                        平日, へいじつ, ひらび
# 77                            祝日, しゅくじつ
# 78                        年末年始, ねんまつねんし
# 79                        案内, あんない, あない
# 80                             翌日, よくじつ
# 81                        前日, ぜんじつ, まえび
# 82                              使用, しよう
# 83                              児童, じどう
# 84                        大人, おとな, だいにん
# 85                               都市, とし
# 86                              市民, しみん
# 87                     尚, なお, 猶, 尚お, 猶お
# 88                              但し, ただし
# 89                只, ただ, 唯, 徒, 但, 常, タダ
# 90                              工事, こうじ
# 91                              用紙, ようし
# 92                             記入, きにゅう
# 93                          連絡先, れんらくさき
# 94                        提出, ていしゅつ, 堤出
# 95                             窓口, まどぐち
# 96                                    や
# 97                            預かる, あずかる
# 98                            預ける, あずける
# 99                             変更, へんこう
# 100                            変換, へんかん
# 101                      開発, かいはつ, かいほつ
# 102                             身分, みぶん
# 103                   身分証明書, みぶんしょうめいしょ
# 104                            報告, ほうこく
# 105                         報告書, ほうこくしょ
# 106                               塩, しお
# 107                            鉄, てつ, 鐵
# 108              打つ, うつ, 拍つ, 搏つ, 撲つ, 擣つ
# 109    追いかける, おいかける, 追い掛ける, 追い駆ける, 追掛ける
# 110                            来店, らいてん
# 111           誠に, まことに, 真に, 寔に, 洵に, しんに
# 112                                 ポスト
# 113                            内容, ないよう
# Name: Word, dtype: object

# %%
a = vocab_data[vocab_data["List"].str.contains("N3_06")]

# %% [markdown]
# MAN YOU SEE LAST VOCAB LIST I GIVE, I HAVE 40 LESSON LIKE THAT TO PASS N3,
#
# HERE THE SECOND LESSON VOCABULARY , GIVE BEST SENTENCE TO MEMORIZE THIS EASILY, TRY TO MAKE SENTENCE HAVE MANY KANJI TO IMPROVE MY KANJI KNOWNLEDGE
#
# ---

# %% [markdown]
# HERE THE N5 1st LESSON VOCABULARY , GIVE BEST SENTENCE TO COVER ALL LESSON 1 VOCAB AND TO MEMORIZE THIS EASILY, TRY TO MAKE SENTENCE HAVE MANY KANJI TO IMPROVE MY KANJI KNOWNLEDGE
# GIVE SENTENCE FOR REMAINING LESSON 1 VOCAB, TO COVER ALL LESSON 1 VOCAB

# %%
print(len(a))
a.columns
# Out:
# 66
# Index(['List', 'ID', 'Time', 'Word', 'Translation'], dtype='object')

# %%
a.head(35)
# Out:
#          List       ID          Time                 Word  \
# 408  N3\N3_06  1538820  6.384802e+17      輸出, ゆしゅつ, しゅしゅつ
# 409  N3\N3_06  1538870  6.384802e+17      輸入, ゆにゅう, しゅにゅう
# 410  N3\N3_06  1538840  6.384802e+17         輸出入, ゆしゅつにゅう
# 411  N3\N3_06  1327730  6.384802e+17         手持ち, てもち, 手持
# 412  N3\N3_06  1606620  6.384802e+17        我が, わが, 我, 吾が
# 413  N3\N3_06  1288810  6.384802e+17  此処, ここ, 此所, 是, 茲, 爰
# 414  N3\N3_06  1455100  6.384802e+17             特製, とくせい
# 415  N3\N3_06  1340820  6.384802e+17   述べる, のべる, 宣べる, 陳べる
# 416  N3\N3_06  1228680  6.384802e+17        急激, きゅうげき, 急劇
# 417  N3\N3_06  1293700  6.384802e+17    最も, もっとも, 尤も, もとも
# 418  N3\N3_06  1546670  6.384802e+17             要因, よういん
# 419  N3\N3_06  1375650  6.384802e+17              成果, せいか
# 420  N3\N3_06  1353450  6.384802e+17           上昇, じょうしょう
# 421  N3\N3_06  1263210  6.384802e+17            減少, げんしょう
# 422  N3\N3_06  1403160  6.384802e+17              増加, ぞうか
# 423  N3\N3_06  1175820  6.384802e+17             円高, えんだか
# 424  N3\N3_06  1175620  6.384802e+17             円安, えんやす
# 425  N3\N3_06  1426670  6.384802e+17            注目, ちゅうもく
# 426  N3\N3_06  1401510  6.384802e+17             総額, そうがく
# 427  N3\N3_06  1489350  6.384802e+17               表, ひょう
# 428  N3\N3_06  1370320  6.384802e+17              図, ず, 圖
# 429  N3\N3_06  1298110  6.384802e+17             削減, さくげん
# 430  N3\N3_06  1450590  6.384802e+17             透明, とうめい
# 431  N3\N3_06  1422720  6.384802e+17             茶色, ちゃいろ
# 432  N3\N3_06  1316040  6.384802e+17               時期, じき
# 433  N3\N3_06  1250190  6.384802e+17             契約, けいやく
# 434  N3\N3_06  1254670  6.384802e+17              結ぶ, むすぶ
# 435  N3\N3_06  1611970  6.384802e+17              明治, めいじ
# 436  N3\N3_06  1414250  6.384802e+17            大正, たいしょう
# 437  N3\N3_06  1349820  6.384802e+17             昭和, しょうわ
# 438  N3\N3_06  1608110  6.384802e+17             平成, へいせい
# 439  N3\N3_06  1503870  6.384802e+17             分析, ぶんせき
# 440  N3\N3_06  1361650  6.384802e+17              新規, しんき
# 441  N3\N3_06  1100850  6.384802e+17                パートナー
# 442  N3\N3_06  1554640  6.384802e+17               量, りょう
#
#                                            Translation
# 408                    export, exportation, , efferent
# 409  import, importation, introduction, இறக்குமதி, ...
# 410                                  export and import
# 411  in hand, on hand, on one, in stock, in store, ...
# 412                                 my, our, one's own
# 413  here, this place, , this point, now, these pas...
# 414                               special make, deluxe
# 415  to state, to express, to say, to tell, to mention
# 416     sudden, abrupt, rapid, sharp, drastic, radical
# 417                                    most, extremely
# 418                         main cause, primary factor
# 419  (good) result, outcome, fruits (of one's labor...
# 420                        rising, ascending, climbing
# 421                       decrease, reduction, decline
# 422        increase, rise, growth, addition, increment
# 423                appreciation of the yen, strong yen
# 424                  depreciation of the yen, weak yen
# 425     notice, attention, observation, கவனம், நாட்டம்
# 426                            sum total, total amount
# 427       table, chart, list, , memorial to an emperor
# 428  drawing, picture, diagram, figure, illustratio...
# 429                        cut, reduction, curtailment
# 430                                 transparent, clear
# 431                 brown, light brown, tawny, பழுப்பு
# 432          time, season, period, phase, stage, காலம்
# 433            contract, compact, agreement, ஒப்பந்தம்
# 434  to tie, to bind, to link, , to bear (fruit), t...
# 435       Meiji era (1868.9.8-1912.7.30), மெய்சி காலம்
# 436                  Taishō era (1912.7.30-1926.12.25)
# 437  Shōwa era (1926.12.25-1989.1.7), , reminiscent...
# 438                    Heisei era (1989.1.8-2019.4.30)
# 439                              analysis, பகுப்பாய்வு
# 440  new, fresh, , new item (e.g. customer, regulat...
# 441          (dance) partner, , (work) partner, spouse
# 442  quantity, amount, volume, capacity, portion (o...

# %%
a.tail(35)
# Out:
#          List       ID          Time                           Word  \
# 439  N3\N3_06  1503870  6.384802e+17                       分析, ぶんせき
# 440  N3\N3_06  1361650  6.384802e+17                        新規, しんき
# 441  N3\N3_06  1100850  6.384802e+17                          パートナー
# 442  N3\N3_06  1554640  6.384802e+17                         量, りょう
# 443  N3\N3_06  1326410  6.384802e+17                      主流, しゅりゅう
# 444  N3\N3_06  1429200  6.384802e+17                      調整, ちょうせい
# 445  N3\N3_06  1351730  6.384802e+17            詳しい, くわしい, 精しい, 委しい
# 446  N3\N3_06  1204860  6.384802e+17                          各, かく
# 447  N3\N3_06  1456420  6.384802e+17                 読書, どくしょ, とくしょ
# 448  N3\N3_06  1208360  6.384802e+17                       活動, かつどう
# 449  N3\N3_06  1124300  6.384802e+17                         ボランティア
# 450  N3\N3_06  1161730  6.384802e+17                      一気に, いっきに
# 451  N3\N3_06  1164950  6.384802e+17                一定, いってい, いちじょう
# 452  N3\N3_06  1162980  6.384802e+17                     一時的, いちじてき
# 453  N3\N3_06  1595480  6.384802e+17      徐々に, じょじょに, 徐徐に, 除々に, 除除に
# 454  N3\N3_06  1414870  6.384802e+17                   大幅, おおはば, 大巾
# 455  N3\N3_06  1603950  6.384802e+17  益々, ますます, 増々, 益益, 増す増す, 増増, 益
# 456  N3\N3_06  1386470  6.384802e+17                    説明書, せつめいしょ
# 457  N3\N3_06  1538200  6.384802e+17                      薬局, やっきょく
# 458  N3\N3_06  1158950  6.384802e+17                        違反, いはん
# 459  N3\N3_06  1258000  6.384802e+17                       検討, けんとう
# 460  N3\N3_06  1464380  6.384802e+17                       日米, にちべい
# 461  N3\N3_06  1215810  6.384802e+17                       関係, かんけい
# 462  N3\N3_06  1268770  6.384802e+17                        互い, たがい
# 463  N3\N3_06  1409540  6.384802e+17                      体重, たいじゅう
# 464  N3\N3_06  1365770  6.384802e+17                      身長, しんちょう
# 465  N3\N3_06  1334150  6.384802e+17                      住宅, じゅうたく
# 466  N3\N3_06  1237110  6.384802e+17                      教材, きょうざい
# 467  N3\N3_06  1436360  6.384802e+17                      提供, ていきょう
# 468  N3\N3_06  1606810  6.384802e+17                 割合, わりあい, 割り合い
# 469  N3\N3_06  1389460  6.384802e+17                       占める, しめる
# 470  N3\N3_06  1350320  6.384802e+17                    消費税, しょうひぜい
# 471  N3\N3_06  1382100  6.384802e+17                       税金, ぜいきん
# 472  N3\N3_06  1386350  6.384802e+17                       節約, せつやく
# 473  N3\N3_06  1239380  6.384802e+17                      業界, ぎょうかい
#
#                                            Translation
# 439                              analysis, பகுப்பாய்வு
# 440  new, fresh, , new item (e.g. customer, regulat...
# 441          (dance) partner, , (work) partner, spouse
# 442  quantity, amount, volume, capacity, portion (o...
# 443  (the) mainstream, , main course (of a river), ...
# 444  adjustment, regulation, coordination, reconcil...
# 445  detailed, full, minute, , knowing very well, k...
# 446                          each, every, all, ஒவ்வொரு
# 447                        reading (a book), வாசித்தல்
# 448  activity (of a person, organization, animal, v...
# 449                          volunteer, தன்னார்வப் பணி
# 450  in one go, in one gulp, in one breath, without...
# 451  fixed, settled, constant, definite, uniform, r...
# 452                 temporary, transitory, short-lived
# 453  gradually, steadily, slowly, little by little,...
# 454  big, large, drastic, substantial, , full-width...
# 455  increasingly, more and more, decreasingly (whe...
# 456  (printed) instructions, manual, explanatory le...
# 457  pharmacy, drugstore, chemist's (shop), மருந்தக...
# 458  violation, offense, offence, breach, transgres...
# 459  consideration, examination, investigation, stu...
# 460     Japan and the United States, Japanese-American
# 461  relation, relationship, connection, , particip...
# 462                            each other, one another
# 463                                      (body) weight
# 464                          height (of body), stature
# 465           residence, housing, residential building
# 466                                 teaching materials
# 467  offer, tender, providing, supplying, making av...
# 468  rate, ratio, percentage, proportion, , compara...
# 469  to occupy, to hold, கணக்கு, , to account for, ...
# 470  consumption tax (incl. sales tax, VAT, excise ...
# 471                                     tax, duty, வரி
# 472                                economising, saving
# 473   business world, business circles, (the) industry

# %%
k = vocab_data[vocab_data["List"].str.contains("N3_07")]

# %%
len(k)
# Out:
# 61

# %%
k.head(35)
# Out:
#          List       ID          Time                            Word  \
# 474  N3\N3_07  1419570  6.384805e+17                   断る, ことわる, 断わる
# 475  N3\N3_07  1452500  6.384806e+17                         同時, どうじ
# 476  N3\N3_07  1046340  6.384806e+17                     グラウンド, グランド
# 477  N3\N3_07  1331020  6.384806e+17                          周, しゅう
# 478  N3\N3_07  1551710  6.384806e+17                         立場, たちば
# 479  N3\N3_07  1312130  6.384806e+17                         視点, してん
# 480  N3\N3_07  1263770  6.384806e+17                       現状, げんじょう
# 481  N3\N3_07  1271310  6.384806e+17                         誤解, ごかい
# 482  N3\N3_07  1484060  6.384806e+17                         秘書, ひしょ
# 483  N3\N3_07  1212110  6.384806e+17                         幹事, かんじ
# 484  N3\N3_07  1157970  6.384806e+17                         異動, いどう
# 485  N3\N3_07  1649500  6.384806e+17               音楽家, おんがくか, おんがっか
# 486  N3\N3_07  1193290  6.384806e+17                         歌手, かしゅ
# 487  N3\N3_07  1538330  6.384806e+17                           訳, わけ
# 488  N3\N3_07  1331670  6.384806e+17                      就職, しゅうしょく
# 489  N3\N3_07  1117030  6.384806e+17                              プロ
# 490  N3\N3_07  1428240  6.384806e+17                       挑戦, ちょうせん
# 491  N3\N3_07  1497680  6.384806e+17                  父親, ちちおや, てておや
# 492  N3\N3_07  1515120  6.384806e+17                        母親, ははおや
# 493  N3\N3_07  1309950  6.384806e+17                         指導, しどう
# 494  N3\N3_07  1189600  6.384806e+17                          価値, かち
# 495  N3\N3_07  1480670  6.384806e+17                        反対, はんたい
# 496  N3\N3_07  1244680  6.384806e+17                     苦労, くろう, 苦勞
# 497  N3\N3_07  1282000  6.384806e+17  行き成り, いきなり, 行成り, 行き成, 行成, ゆきなり
# 498  N3\N3_07  1281000  6.384806e+17                        考え, かんがえ
# 499  N3\N3_07  1156560  6.384806e+17                          意志, いし
# 500  N3\N3_07  1212330  6.384806e+17                        感覚, かんかく
# 501  N3\N3_07  1546590  6.384806e+17  葉書, はがき, 葉書き, 端書, 端書き, 羽書, ハガキ
# 502  N3\N3_07  1198860  6.384806e+17                         会費, かいひ
# 503  N3\N3_07  1207060  6.384806e+17                         学費, がくひ
# 504  N3\N3_07  1589820  6.384806e+17           香り, かおり, 薫り, 馨り, 香, 薫
# 505  N3\N3_07  1472260  6.384806e+17                        拝啓, はいけい
# 506  N3\N3_07  1250740  6.384806e+17                         敬具, けいぐ
# 507  N3\N3_07  1251250  6.384806e+17                         経過, けいか
# 508  N3\N3_07  1374810  6.384806e+17                        制作, せいさく
#
#                                            Translation
# 474  to refuse, to reject, to dismiss, to turn down...
# 475  simultaneous, concurrent, same time, synchrono...
# 476      field, sports ground, sports oval, playground
# 477  counter for laps or circuits, சவு அரசமரபு, , p...
# 478  position, situation, நிலை, , viewpoint, standp...
# 479               opinion, point of view, visual point
# 480  present condition, existing state, status quo,...
# 481                                   misunderstanding
# 482  (private) secretary, நிறுவனத்தின் செயலாளர், , ...
# 483  executive secretary, coordinator, organizer, p...
# 484  (personnel) change, transfer, relocation, reas...
# 485                                           musician
# 486                                     singer, பாடகர்
# 487  conclusion from reasoning, judgement or calcul...
# 488                  finding employment, getting a job
# 489                                       professional
# 490     challenge, defiance, dare, attempt, try, சவால்
# 491                                      father, தந்தை
# 492                                       mother, தாய்
# 493  guidance, leadership, instruction, direction, ...
# 494                       value, worth, merit, மதிப்பு
# 495  opposition, resistance, antagonism, hostility,...
# 496  trouble, hardship, difficulty, labour, labor, ...
# 497  abruptly, suddenly, all of a sudden, without w...
# 498  thinking, thought, view, opinion, concept, எண்...
# 499  will, volition, intention, intent, determinati...
# 500               sense, sensation, feeling, intuition
# 501                       postcard, , memo, note, card
# 502                                     membership fee
# 503                           tuition, school expenses
# 504                     aroma, fragrance, scent, smell
# 505  Dear (so and so), Dear Sir, Dear Madam, To Who...
# 506      Yours sincerely, Yours truly, Sincerely yours
# 507  passage (of time), elapsing, lapse, , progress...
# 508  work (film, book), , production, creation, tur...

# %%
k.tail(35)
# Out:
#          List       ID          Time                            Word  \
# 500  N3\N3_07  1212330  6.384806e+17                        感覚, かんかく
# 501  N3\N3_07  1546590  6.384806e+17  葉書, はがき, 葉書き, 端書, 端書き, 羽書, ハガキ
# 502  N3\N3_07  1198860  6.384806e+17                         会費, かいひ
# 503  N3\N3_07  1207060  6.384806e+17                         学費, がくひ
# 504  N3\N3_07  1589820  6.384806e+17           香り, かおり, 薫り, 馨り, 香, 薫
# 505  N3\N3_07  1472260  6.384806e+17                        拝啓, はいけい
# 506  N3\N3_07  1250740  6.384806e+17                         敬具, けいぐ
# 507  N3\N3_07  1251250  6.384806e+17                         経過, けいか
# 508  N3\N3_07  1374810  6.384806e+17                        制作, せいさく
# 509  N3\N3_07  1421060  6.384806e+17                         地元, じもと
# 510  N3\N3_07  1016950  6.384806e+17                            アトリエ
# 511  N3\N3_07  1264540  6.384806e+17              言葉, ことば, 詞, 辞, けとば
# 512  N3\N3_07  1518080  6.384806e+17               訪れる, おとずれる, おとづれる
# 513  N3\N3_07  1557390  6.384806e+17                         励む, はげむ
# 514  N3\N3_07  1557350  6.384806e+17                       励ます, はげます
# 515  N3\N3_07  1535170  6.384806e+17            目まぐるしい, めまぐるしい, 目紛しい
# 516  N3\N3_07  1361560  6.384806e+17                      新学期, しんがっき
# 517  N3\N3_07  2087880  6.385233e+17                       勤しむ, いそしむ
# 518  N3\N3_07  1592500  6.385233e+17      具合, ぐあい, 工合, 具合い, 工合い, ぐわい
# 519  N3\N3_07  1257420  6.385233e+17                        建設, けんせつ
# 520  N3\N3_07  1269510  6.385233e+17                        後悔, こうかい
# 521  N3\N3_07  1509490  6.385233e+17                         別れ, わかれ
# 522  N3\N3_07  1360680  6.385233e+17                     心細い, こころぼそい
# 523  N3\N3_07  1360640  6.385233e+17                     心強い, こころづよい
# 524  N3\N3_07  1610990  6.385233e+17                  夏バテ, なつばて, 夏ばて
# 525  N3\N3_07  1342580  6.385233e+17                   初夏, しょか, はつなつ
# 526  N3\N3_07  1637290  6.385233e+17                       新春, しんしゅん
# 527  N3\N3_07  1535490  6.385233e+17                         目上, めうえ
# 528  N3\N3_07  1250830  6.385233e+17                         景気, けいき
# 529  N3\N3_07  1546680  6.385233e+17                       要求, ようきゅう
# 530  N3\N3_07  1219910  6.385233e+17                     希望, きぼう, 冀望
# 531  N3\N3_07  1006570  6.385233e+17                             せめて
# 532  N3\N3_07  1606000  6.385233e+17           夜更かし, よふかし, 夜更し, 夜ふかし
# 533  N3\N3_07  1372800  6.385233e+17               随分, ずいぶん, ずい分, 隨分
# 534  N3\N3_07  1557950  6.385233e+17                      暦, こよみ, れき
#
#                                            Translation
# 500               sense, sensation, feeling, intuition
# 501                       postcard, , memo, note, card
# 502                                     membership fee
# 503                           tuition, school expenses
# 504                     aroma, fragrance, scent, smell
# 505  Dear (so and so), Dear Sir, Dear Madam, To Who...
# 506      Yours sincerely, Yours truly, Sincerely yours
# 507  passage (of time), elapsing, lapse, , progress...
# 508  work (film, book), , production, creation, tur...
# 509                      home area, home town, , local
# 510                          atelier, studio, workshop
# 511  language, dialect, வார்த்தை, சொல், , word, phr...
# 512  to visit, to call on, , to arrive (season, tim...
# 513  to work hard, to try hard, to strive, to endea...
# 514  to encourage, to cheer on, to cheer (someone) ...
# 515  dizzying (speed, changes, etc.), rapid, drasti...
# 516                                    new school term
# 517  to work hard at, to devote oneself to, to be d...
# 518  condition, state, , health, state (of health),...
# 519                        construction, establishment
# 520              regret, repentance, remorse, வருத்தம்
# 521                      parting, separation, farewell
# 522  helpless, forlorn, hopeless, unpromising, lone...
# 523                             heartening, reassuring
# 524    suffering from summer heat, summer heat fatigue
# 525  early summer, , fourth month of the lunar cale...
# 526                                           New Year
# 527                        superior, superiors, senior
# 528  business conditions, the market, economic acti...
# 529  demand, firm request, requisition, requirement...
# 530  hope, wish, aspiration, நம்பிக்கை, , (bright) ...
# 531                     at least, at most, (even) just
# 532  staying up late, keeping late hours, sitting u...
# 533  very, extremely, surprisingly, considerably, a...
# 534                      calendar, almanac, நாட்காட்டி

# %%
# Out:
# /home/aurexus/Documents/Anki/notebook/Bankai/bin/python
