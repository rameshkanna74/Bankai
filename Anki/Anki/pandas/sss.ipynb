# %%
print("Boombox baby")
# Out:
# Boombox baby

# %%
from bs4 import BeautifulSoup

# Read the HTML file
with open("test.html", "r", encoding="utf-8") as file:
    html_content = file.read()

# Parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the specific div by class name
div = soup.find("div", class_="last_episodes")

# Check if the div exists
if div:
    # Find all anchor tags within the div
    anchors = div.find_all("a")

    # Print out the href attributes of the anchor tags
    for anchor in anchors:
        print(anchor.get("href"))
else:
    print("No div with class 'last_episodes' found.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from bs4 import BeautifulSoup
#       3 # Read the HTML file
# ----> 4 with open("test.html", "r", encoding="utf-8") as file:
#       5     html_content = file.read()
#       7 # Parse the HTML
#
# File ~/Documents/Anki/notebook/Bankai/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.html'

# %%
anime_titles = [
    "2-5-jigen-no-ririsa",
    "anti-routine-system-season-2",
    "date-a-live-v-dub",
    "divine-heros-skyfall-system",
    "emperor-son-in-law",
    "i-have-a-little-too-much-nascent-souls",
    "i-really-dont-want-to-be-the-first",
    "i-was-forced-by-the-system-to-become-a-villain",
    "im-stuck-on-the-same-day-for-a-thousand-years",
    "kekkon-yubiwa-monogatari",
    "kekkon-yubiwa-monogatari-dub",
    "logging-10000-years-into-the-future",
    "lucky-me-i-secretly-cultivated-for-1000-years",
    "mato-seihei-no-slave",
    "mato-seihei-no-slave-dub",
    "my-apocalyptic-miss",
    "my-seven-sisters-are-unparalleled",
    "my-wife-is-a-heavenly-big-shot",
    "nightwatcher",
    "starting-out-with-max-favorability",
]

# %%
import subprocess

# List of anime titles to get direct download links for
anime_titles = [
    "2-5-jigen-no-ririsa",
    "anti-routine-system-season-2",
    "date-a-live-v-dub",
    "divine-heros-skyfall-system",
    "emperor-son-in-law",
    "i-have-a-little-too-much-nascent-souls",
    "i-really-dont-want-to-be-the-first",
    "i-was-forced-by-the-system-to-become-a-villain",
    "im-stuck-on-the-same-day-for-a-thousand-years",
    "kekkon-yubiwa-monogatari",
    "kekkon-yubiwa-monogatari-dub",
    "logging-10000-years-into-the-future",
    "lucky-me-i-secretly-cultivated-for-1000-years",
    "mato-seihei-no-slave",
    "mato-seihei-no-slave-dub",
    "my-apocalyptic-miss",
    "my-seven-sisters-are-unparalleled",
    "my-wife-is-a-heavenly-big-shot",
    "nightwatcher",
    "starting-out-with-max-favorability",
]


# Function to run senpcli command and get direct download links
def get_direct_download_links(title):
    command = [
        "senpcli",
        "-ddl",  # Option to get direct download links
        "-q",
        "480p",  # Quality: 480p
        "-sd",
        "sub",  # Subbed version
        title,
    ]
    try:
        # Execute the command and capture the output
        result = subprocess.run(command, check=True, text=True, capture_output=True)
        print(f"Direct download links for: {title}")
        print(result.stdout)  # Print the output of the command
    except subprocess.CalledProcessError as e:
        print(f"Error occurred while getting DDL for {title}: {e}")


# Iterate over the list of anime titles and get direct download links for each",
for title in anime_titles:
    print(title)
    # get_direct_download_links(title)

# %%
# List of anime titles to download
anime_titles = [
    # "isekai-ojisan",
    # "hazurewaku-no-joutai-ijou-skill-de-saikyou-ni-natta-ore-ga-subete-wo-juurin-suru-made",
    # "tsugumomo",
    # "Sekirei",
    # "freezing",
    # "mahou-sensei-negima",
    # "date-a-live",
    # "date-a-live-ii",
    # "date-a-live-iii",
    # "date-a-live-iv",
    # "date-a-live-v",
    # "High-School-DxD",
    # "",
]


# Function to run senpcli command
def run_senpcli(title):
    command = [
        "senpcli",
        "-s",
        "gogo",  # Site: gogo
        "-q",
        "480p",  # Quality: 480p
        "-sd",
        "sub",  # Subbed version
        # "-se",
        # "1",  # Start episode (1)
        # "-ee",
        # "1000",  # End episode (1000) - adjust if needed
        title,
    ]
    try:
        # Execute the command and wait for it to complete
        subprocess.run(command, check=True)
        print(f"Download started for: {title}")
    except subprocess.CalledProcessError as e:
        print(f"Error occurred while downloading {title}: {e}")


# Iterate over the list of anime titles and download each
for title in anime_titles:
    run_senpcli(title)
    # print(title)

# %% [markdown]
# # Front
# <div class="front">
#     <h1>{{English_Translation}}</h1>
# </div>
#
# # Back
# <div class="back">
#     <h2>{{English_Translation}}</h2>
#     <div class="details">
#     <table>
#         <tr>
#             <td><strong>No.</strong></td>
#             <td>{{No.}}</td>
#         </tr>
#         <tr>
#             <td><strong>Kanji</strong></td>
#             <td>{{Japanese(Kanji)}}</td>
#         </tr>
#         <tr>
#             <td><strong>Hiragana</strong></td>
#             <td>{{Hiragana}}</td>
#         </tr>
#         <tr>
#             <td><strong>Romaji</strong></td>
#             <td>{{Romaji}}</td>
#         </tr>
#         <tr>
#             <td><strong>English</strong></td>
#             <td>{{English_Translation}}</td>
#         </tr>
#         <tr>
#             <td><strong>Part of Speech</strong></td>
#             <td>{{Part_of_speech}}</td>
#         </tr>
#         <tr>
#             <td><strong>Example (Japanese)</strong></td>
#             <td>{{Example_Sentence(Japanese)}}</td>
#         </tr>
#         <tr>
#             <td><strong>Example (English)</strong></td>
#             <td>{{Example_Sentence(English)}}</td>
#         </tr>
#         <tr>
#             <td><strong>Example (Romaji)</strong></td>
#             <td>{{Example_Sentence(Romaji)}}</td>
#         </tr>
#         <tr>
#             <td><strong>Notes</strong></td>
#             <td>{{Notes}}</td>
#         </tr>
#     </table>
#     </div>
# </div>
#
#
# # Style
# /* Main Heading (Front and Back) */
# h1, h2 {
#     text-align: center;
#     color: #f38ba8; /* Soft pink color for the headings */
#     font-family: 'Arial', sans-serif; /* Clean, readable font */
#     margin: 0;
# }
#
# /* Back card design */
# .back {
#     padding: 20px; /* Increased padding for better spacing */
#     background-color: #11111b; /* Dark background for better contrast */
#     border-radius: 12px;
#     box-shadow: 0px 4px 20px rgba(0, 0, 0, 0.5);
#     font-family: 'Arial', sans-serif; /* Consistent font family */
# }
#
# /* Table structure */
# table {
#     width: 100%;
#     max-width: 800px;
#     margin: 0 auto;
#     border-collapse: collapse;
#     background-color: #313244; /* Dark gray background for the table */
#     border-radius: 8px;
#     overflow: hidden;
#     table-layout: auto;
# }
#
# /* Table, Headers, and Data Cells */
# table, th, td {
#     border: 1px solid #45475a; /* Softer borders with a dark hue */
#     padding: 12px; /* Increased padding for better readability */
#     text-align: left;
# }
#
# /* Headers (th) */
# th {
#     background-color: #585b70; /* Light gray-purple header for better contrast */
#     color: #cdd6f4; /* Light text for good visibility */
#     font-weight: bold;
#     font-size: 18px;
# }
#
# /* Table data cells (td) */
# td {
#     color: #bac2de; /* Softer light gray for text */
#     font-size: 14px;
# }
#
# /* Zebra stripes for readability */
# tr:nth-child(even) {
#     background-color: #282838; /* Slightly different dark background */
# }
#
# tr:nth-child(odd) {
#     background-color: #161620; /* Adjusted to ensure good contrast */
# }
#
# /* Hover effect for rows */
# tr:hover {
#     background-color: #1e1e2e; /* Slightly lighter background on hover */
#     cursor: pointer;
# }
#
# /* Details section */
# .details p {
#     margin: 10px 0;
#     color: #d0d0d0;
# }
#
# /* Horizontal rule styling */
# hr#answer {
#     border: 0;
#     height: 3px;
#     background: #4a4a4a;
#     margin: 20px 0;
# }
#
# /* Responsive design adjustments */
# @media (max-width: 600px) {
#     table {
#         font-size: 13px;
#     }
#
#     th, td {
#         padding: 10px;
#         display: block;
#         width: 100%;
#     }
#
#
#     tr {
#         display: flex;
#         flex-direction: column;
#         margin-bottom: 15px;
#     }
#
#     tr:hover {
#         background-color: transparent;
#     }
# }
