// %% [markdown]
// Provide the **most optimized, production-quality, and interview-ready Rust solution** for the following DSA problem:
//
// ### Problem:
//
// 73. Set Matrix Zeroes
//     Medium
//     Topics
//     Companies
//     Hint
//
// Given an m x n integer matrix matrix, if an element is 0, set its entire row and column to 0's.
//
// You must do it in place.
//
// Example 1:
//
// Input: matrix = [[1,1,1],[1,0,1],[1,1,1]]
// Output: [[1,0,1],[0,0,0],[1,0,1]]
// Example 2:
//
// Input: matrix = [[0,1,2,0],[3,4,5,2],[1,3,1,5]]
// Output: [[0,0,0,0],[0,4,5,0],[0,3,1,0]]
//
// Constraints:
//
// m == matrix.length
// n == matrix[0].length
// 1 <= m, n <= 200
// -231 <= matrix[i][j] <= 231 - 1
//
// Follow up:
//
// A straightforward solution using O(mn) space is probably a bad idea.
// A simple improvement uses O(m + n) space, but still not the best solution.
// Could you devise a constant space solution?
//
// ### Typing
//
// ```rust
// impl Solution {
//     pub fn set_zeroes(matrix: &mut Vec<Vec<i32>>) {
//
//     }
// }
// ```
//
// ---
//
// ### Requirements:
//
// 🔹 **Optimal Time Complexity**
//
// - State the algorithm's time complexity and justify why it is optimal given the problem constraints.
//
// 🔹 **Optimal Space Complexity**
//
// - Minimize extra space usage and explain the space complexity.
//
// 🔹 **Rust Code Quality**
//
// - Use **clean, idiomatic, modular Rust code** suitable for **FAANG/MAANG interviews**.
// - Follow **ownership, borrowing, and iterator best practices**.
// - Include **realistic interview-level function signatures** (`fn solve(...) -> ...`).
// - Avoid unnecessary `unwrap()`, `expect()`, or unsafe code unless clearly justified.
// - Handle all **edge cases** thoughtfully within the code.
// - Provide **unit tests** (`#[test]`) for common and edge cases.
//
// 🔹 **Algorithm Explanation**
//
// - Describe the **core DSA concepts** used (e.g., Greedy, DP, Binary Search).
// - Explain the **algorithm design, reasoning**, and why this is the most optimal approach.
// - Discuss any **critical trade-offs** made.
// - Identify common **edge cases** and explain how they are handled.
//
// 🔹 **Constraints & Scalability**
//
// - Analyze the solution's behavior under **maximum input sizes**.
// - Confirm it passes **stress tests** without significant performance degradation.
//
// 🔹 **DSA Tags**
//
// - Suggest relevant DSA topics (e.g., Arrays, Trees, Graphs, Dynamic Programming, Sliding Window).
//
// 🔹 **Follow-up Enhancements (Optional)**
//
// - How would the solution adapt to **streaming input**, **parallelization**, or **distributed systems**?
// - What are potential **real-world applications** of this approach?

// %% [markdown]
// # 🚀 **Optimized, Production-Quality Rust Solution for Set Matrix Zeroes (`O(1)` Space)**
//
// ---
//
// ## **📌 Problem Breakdown**
//
// ### **Task**
//
// - Given an `m x n` matrix, if an element is `0`, set its **entire row and column** to `0`, **in-place**.
//
// ### **Example**
//
// #### **Input:**
//
// ```rust
// matrix = [[1,1,1],
//           [1,0,1],
//           [1,1,1]]
// ```
//
// #### **Output:**
//
// ```rust
// matrix = [[1,0,1],
//           [0,0,0],
//           [1,0,1]]
// ```
//
// #### **Input:**
//
// ```rust
// matrix = [[0,1,2,0],
//           [3,4,5,2],
//           [1,3,1,5]]
// ```
//
// #### **Output:**
//
// ```rust
// matrix = [[0,0,0,0],
//           [0,4,5,0],
//           [0,3,1,0]]
// ```
//
// ### **Constraints**
//
// ✅ `1 ≤ m, n ≤ 200`
// ✅ `-2³¹ ≤ matrix[i][j] ≤ 2³¹ - 1`
//
// ---
//
// ## **📊 Time & Space Complexity Analysis**
//
// | **Approach**                                   | **Time Complexity** | **Space Complexity** | **Why?**                             |
// | ---------------------------------------------- | ------------------- | -------------------- | ------------------------------------ |
// | **Brute Force (`O(m × n)`)**                   | `O(m × n)`          | `O(m × n)`           | Extra matrix to track zero locations |
// | **Using Extra Row & Col Arrays (`O(m + n)`)**  | `O(m × n)`          | `O(m + n)`           | Uses extra arrays to track zeroes    |
// | **In-Place Using First Row & Col (`O(1)`) ✅** | `O(m × n)`          | `O(1)`               | Uses first row & col as flags        |
//
// ✅ **Best Choice: In-Place Solution (`O(1)` Space, `O(m × n)` Time)**
//
// - **Uses first row & column as flags** instead of extra arrays.
// - **Efficient and scalable** for `m, n = 200`.
//
// ---
//
// ## **📌 Optimized Rust Code (`O(1)` Space)**
//
// ```rust
// impl Solution {
//     pub fn set_zeroes(matrix: &mut Vec<Vec<i32>>) {
//         let (m, n) = (matrix.len(), matrix[0].len());
//         let mut first_col_zero = false;
//
//         // Step 1: Mark zeroes using first row and first column
//         for i in 0..m {
//             if matrix[i][0] == 0 {
//                 first_col_zero = true;
//             }
//             for j in 1..n {
//                 if matrix[i][j] == 0 {
//                     matrix[i][0] = 0; // Mark row
//                     matrix[0][j] = 0; // Mark column
//                 }
//             }
//         }
//
//         // Step 2: Set zeroes based on marks
//         for i in (1..m) {
//             for j in (1..n) {
//                 if matrix[i][0] == 0 || matrix[0][j] == 0 {
//                     matrix[i][j] = 0;
//                 }
//             }
//         }
//
//         // Step 3: Handle first row
//         if matrix[0][0] == 0 {
//             for j in 0..n {
//                 matrix[0][j] = 0;
//             }
//         }
//
//         // Step 4: Handle first column
//         if first_col_zero {
//             for i in 0..m {
//                 matrix[i][0] = 0;
//             }
//         }
//     }
// }
//
// #[cfg(test)]
// mod tests {
//     use super::Solution;
//
//     #[test]
//     fn test_set_zeroes() {
//         let mut matrix1 = vec![vec![1,1,1], vec![1,0,1], vec![1,1,1]];
//         Solution::set_zeroes(&mut matrix1);
//         assert_eq!(matrix1, vec![vec![1,0,1], vec![0,0,0], vec![1,0,1]]);
//
//         let mut matrix2 = vec![vec![0,1,2,0], vec![3,4,5,2], vec![1,3,1,5]];
//         Solution::set_zeroes(&mut matrix2);
//         assert_eq!(matrix2, vec![vec![0,0,0,0], vec![0,4,5,0], vec![0,3,1,0]]);
//     }
// }
// ```
//
// ✅ **Time Complexity:** `O(m × n)`
// ✅ **Space Complexity:** `O(1)`
// ✅ **In-Place Solution** 🚀
//
// ---
//
// ## **📌 Algorithm Explanation**
//
// ### **1️⃣ Using First Row & Column as Flags**
//
// - Instead of **using extra memory** to store zero locations, we **reuse the first row and column**.
// - We **mark** which rows & columns should be zeroed.
//
// ### **2️⃣ Steps**
//
// 1. **Mark Zero Locations**
//
//    - Iterate through the matrix.
//    - If `matrix[i][j] == 0`, mark `matrix[i][0] = 0` and `matrix[0][j] = 0`.
//    - Track separately if the **first column itself should be zeroed**.
//
// 2. **Update Non-First Row & Column**
//
//    - Use `matrix[i][0]` and `matrix[0][j]` as reference flags.
//    - If either is `0`, set `matrix[i][j] = 0`.
//
// 3. **Update First Row & Column**
//    - If `matrix[0][0] == 0`, zero the first row.
//    - If `first_col_zero == true`, zero the first column.
//
// ---
//
// ## **📌 Edge Cases Considered**
//
// | **Case**                   | **Handled?**                 |
// | -------------------------- | ---------------------------- |
// | Matrix with all `0`s       | ✅ Returns all `0`s          |
// | Matrix with no `0`s        | ✅ Remains unchanged         |
// | Single row/column          | ✅ Properly updates          |
// | Large matrix (`200 × 200`) | ✅ Efficient in `O(1)` space |
//
// ---
//
// ## **📌 Follow-Up Enhancements**
//
// ### **1️⃣ Handling Streaming Input (Real-Time Matrix Updates)**
//
// - Use **bitwise tricks** or an external **tracking array**.
// - For **distributed systems**, use **sharded storage**.
//
// ### **2️⃣ Parallelization**
//
// - **Divide matrix into chunks** and use **parallel threads** to process different sections.
//
// ### **3️⃣ Real-World Applications**
//
// - **Image Processing** (Removing corrupted pixels)
// - **Graph Adjacency Matrices** (Eliminating invalid edges)
// - **Database Tables** (Cascading updates based on constraints)
//
// ---
//
// ## **✅ Final Verdict**
//
// ✅ **In-Place (`O(1)`) solution is the most optimal.** 🚀

// %%
impl Solution {
    pub fn set_zeroes(matrix: &mut Vec<Vec<i32>>) {
        let (m, n) = (matrix.len(), matrix[0].len());
        let mut first_col_zero = false;

        // Step 1: Mark zeroes using first row and first column
        for i in 0..m {
            if matrix[i][0] == 0 {
                first_col_zero = true;
            }
            for j in 1..n {
                if matrix[i][j] == 0 {
                    matrix[i][0] = 0; // Mark row
                    matrix[0][j] = 0; // Mark column
                }
            }
        }

        // Step 2: Set zeroes based on marks
        for i in (1..m) {
            for j in (1..n) {
                if matrix[i][0] == 0 || matrix[0][j] == 0 {
                    matrix[i][j] = 0;
                }
            }
        }

        // Step 3: Handle first row
        if matrix[0][0] == 0 {
            for j in 0..n {
                matrix[0][j] = 0;
            }
        }

        // Step 4: Handle first column
        if first_col_zero {
            for i in 0..m {
                matrix[i][0] = 0;
            }
        }
    }
}
