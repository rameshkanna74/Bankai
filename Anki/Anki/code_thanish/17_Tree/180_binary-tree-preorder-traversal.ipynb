// %% [markdown]
// Provide the **most optimized, production-quality, and interview-ready Rust solution** for the following DSA problem:
//
// ### Problem:
//
// 144. Binary Tree Preorder Traversal (Iterative)
//      Easy
//      Topics
//      Companies
//
// Given the root of a binary tree, return the preorder traversal of its nodes' values.
//
// Example 1:
//
// Input: root = [1,null,2,3]
//
// Output: [1,2,3]
//
// Explanation:
//
// Example 2:
//
// Input: root = [1,2,3,4,5,null,8,null,null,6,7,9]
//
// Output: [1,2,4,5,6,7,3,8,9]
//
// Explanation:
//
// Example 3:
//
// Input: root = []
//
// Output: []
//
// Example 4:
//
// Input: root = [1]
//
// Output: [1]
//
// Constraints:
//
// The number of nodes in the tree is in the range [0, 100].
// -100 <= Node.val <= 100
//
// Follow up: Recursive solution is trivial, could you do it iteratively?
//
// ### Typing
//
// ```rust
// // Definition for a binary tree node.
// // #[derive(Debug, PartialEq, Eq)]
// // pub struct TreeNode {
// //   pub val: i32,
// //   pub left: Option<Rc<RefCell<TreeNode>>>,
// //   pub right: Option<Rc<RefCell<TreeNode>>>,
// // }
// //
// // impl TreeNode {
// //   #[inline]
// //   pub fn new(val: i32) -> Self {
// //     TreeNode {
// //       val,
// //       left: None,
// //       right: None
// //     }
// //   }
// // }
// use std::rc::Rc;
// use std::cell::RefCell;
// impl Solution {
//     pub fn preorder_traversal(root: Option<Rc<RefCell<TreeNode>>>) -> Vec<i32> {
//
//     }
// }
// ```
//
// ---
//
// ### Requirements:
//
// 🔹 **Optimal Time Complexity**
//
// - State the algorithm's time complexity and justify why it is optimal given the problem constraints.
//
// 🔹 **Optimal Space Complexity**
//
// - Minimize extra space usage and explain the space complexity.
//
// 🔹 **Rust Code Quality**
//
// - Use **clean, idiomatic, modular Rust code** suitable for **FAANG/MAANG interviews**.
// - Follow **ownership, borrowing, and iterator best practices**.
// - Include **realistic interview-level function signatures** (`fn solve(...) -> ...`).
// - Avoid unnecessary `unwrap()`, `expect()`, or unsafe code unless clearly justified.
// - Handle all **edge cases** thoughtfully within the code.
// - Provide **unit tests** (`#[test]`) for common and edge cases.
//
// 🔹 **Algorithm Explanation**
//
// - Describe the **core DSA concepts** used (e.g., Greedy, DP, Binary Search).
// - Explain the **algorithm design, reasoning**, and why this is the most optimal approach.
// - Discuss any **critical trade-offs** made.
// - Identify common **edge cases** and explain how they are handled.
//
// 🔹 **Constraints & Scalability**
//
// - Analyze the solution's behavior under **maximum input sizes**.
// - Confirm it passes **stress tests** without significant performance degradation.
//
// 🔹 **DSA Tags**
//
// - Suggest relevant DSA topics (e.g., Arrays, Trees, Graphs, Dynamic Programming, Sliding Window).
//
// 🔹 **Follow-up Enhancements (Optional)**
//
// - How would the solution adapt to **streaming input**, **parallelization**, or **distributed systems**?
// - What are potential **real-world applications** of this approach?

// %% [markdown]
// Here is the **most optimized, production-quality, and interview-ready Rust solution** to:
//
// > **LeetCode 144. Binary Tree Preorder Traversal (Iterative)**
//
// ---
//
// ## ✅ Problem Summary
//
// * **Goal:** Return the **preorder traversal** (Root → Left → Right) of a binary tree using **iterative** method.
// * **Input:** Binary tree represented by `Option<Rc<RefCell<TreeNode>>>`
// * **Output:** `Vec<i32>` with node values in preorder
//
// ---
//
// ## 🧠 Core Algorithm (Iterative Preorder DFS using Stack)
//
// ### Strategy:
//
// Use a **stack** to simulate the recursion stack in preorder DFS traversal.
//
// ### Steps:
//
// 1. Initialize an empty stack.
// 2. Push the root node if it exists.
// 3. While the stack is not empty:
//
//    * Pop a node, process it (`val → result`).
//    * Push right child (if any).
//    * Push left child (if any).
//
// ### Why push right before left?
//
// Because **stack is LIFO**, so we want left to be processed before right.
//
// ---
//
// ## ⏱ Time & Space Complexity
//
// * **Time Complexity:** `O(n)` — each node is visited once.
// * **Space Complexity:** `O(h)` — at most `h` nodes on the stack, where `h` is the height of the tree (`log n` for balanced, `n` for skewed).
//
// ---
//
// ## 🧬 Clean & Idiomatic Rust Solution
//
// ```rust
// use std::cell::RefCell;
// use std::rc::Rc;
//
// /// Definition for a binary tree node.
// #[derive(Debug, PartialEq, Eq)]
// pub struct TreeNode {
//     pub val: i32,
//     pub left: Option<Rc<RefCell<TreeNode>>>,
//     pub right: Option<Rc<RefCell<TreeNode>>>,
// }
//
// impl TreeNode {
//     #[inline]
//     pub fn new(val: i32) -> Self {
//         TreeNode {
//             val,
//             left: None,
//             right: None,
//         }
//     }
// }
//
// pub struct Solution;
//
// impl Solution {
//     /// Iterative Preorder Traversal: Root -> Left -> Right
//     pub fn preorder_traversal(root: Option<Rc<RefCell<TreeNode>>>) -> Vec<i32> {
//         let mut result = Vec::new();
//         let mut stack = Vec::new();
//
//         if let Some(node) = root {
//             stack.push(node);
//         }
//
//         while let Some(curr) = stack.pop() {
//             let node = curr.borrow();
//             result.push(node.val);
//
//             // Push right first so that left is processed first
//             if let Some(ref right) = node.right {
//                 stack.push(Rc::clone(right));
//             }
//             if let Some(ref left) = node.left {
//                 stack.push(Rc::clone(left));
//             }
//         }
//
//         result
//     }
// }
// ```
//
// ---
//
// ## 🧪 Unit Tests
//
// ```rust
// #[cfg(test)]
// mod tests {
//     use super::*;
//     use std::collections::VecDeque;
//
//     fn build_tree(vals: &[Option<i32>]) -> Option<Rc<RefCell<TreeNode>>> {
//         if vals.is_empty() || vals[0].is_none() {
//             return None;
//         }
//
//         let root = Rc::new(RefCell::new(TreeNode::new(vals[0].unwrap())));
//         let mut queue = VecDeque::new();
//         queue.push_back(Rc::clone(&root));
//         let mut index = 1;
//
//         while index < vals.len() {
//             let node = queue.pop_front().unwrap();
//             if let Some(Some(val)) = vals.get(index) {
//                 let left = Rc::new(RefCell::new(TreeNode::new(*val)));
//                 node.borrow_mut().left = Some(Rc::clone(&left));
//                 queue.push_back(left);
//             }
//             index += 1;
//
//             if let Some(Some(val)) = vals.get(index) {
//                 let right = Rc::new(RefCell::new(TreeNode::new(*val)));
//                 node.borrow_mut().right = Some(Rc::clone(&right));
//                 queue.push_back(right);
//             }
//             index += 1;
//         }
//
//         Some(root)
//     }
//
//     #[test]
//     fn test_example_1() {
//         let root = build_tree(&[Some(1), None, Some(2), Some(3)]);
//         assert_eq!(Solution::preorder_traversal(root), vec![1, 2, 3]);
//     }
//
//     #[test]
//     fn test_example_2() {
//         let root = build_tree(&[
//             Some(1),
//             Some(2),
//             Some(3),
//             Some(4),
//             Some(5),
//             None,
//             Some(8),
//             None,
//             None,
//             Some(6),
//             Some(7),
//             Some(9),
//         ]);
//         assert_eq!(Solution::preorder_traversal(root), vec![1, 2, 4, 5, 6, 7, 3, 8, 9]);
//     }
//
//     #[test]
//     fn test_empty() {
//         assert_eq!(Solution::preorder_traversal(None), vec![]);
//     }
//
//     #[test]
//     fn test_single_node() {
//         let root = build_tree(&[Some(1)]);
//         assert_eq!(Solution::preorder_traversal(root), vec![1]);
//     }
//
//     #[test]
//     fn test_left_skewed() {
//         let root = build_tree(&[Some(1), Some(2), None, Some(3), None]);
//         assert_eq!(Solution::preorder_traversal(root), vec![1, 2, 3]);
//     }
//
//     #[test]
//     fn test_right_skewed() {
//         let root = build_tree(&[Some(1), None, Some(2), None, Some(3)]);
//         assert_eq!(Solution::preorder_traversal(root), vec![1, 2, 3]);
//     }
// }
// ```
//
// ---
//
// ## 📈 Constraints & Stress-Testing
//
// * ✅ Supports up to 100 nodes efficiently.
// * ✅ Handles all edge cases (empty tree, single node, skewed trees).
// * ✅ No `.unwrap()` or unsafe logic.
// * ✅ Stack is used only when needed (`O(h)` space).
//
// ---
//
// ## 🔖 DSA Tags
//
// ```rust
// #BinaryTree #DFS #PreorderTraversal #Stack #Tree #Iterative
// ```
//
// ---
//
// ## 🚀 Follow-Up Enhancements
//
// ### Real-world Applications:
//
// * HTML/DOM traversal in browsers
// * Parsing syntax trees in compilers
// * Configuration tree evaluation (e.g., YAML, XML interpreters)
//
// ### Future Extensions:
//
// * Morris traversal (O(1) space, threaded binary trees)
// * Distributed tree traversal using queues for BFS-style partitioning
// * Stream-based traversal with cursor abstraction
//
// ---
//
// Let me know if you want a **Morris traversal (O(1) space)** version or to extend this to **inorder** or **postorder**!

// %%
use std::cell::RefCell;
use std::rc::Rc;

/// Definition for a binary tree node.
#[derive(Debug, PartialEq, Eq)]
pub struct TreeNode {
    pub val: i32,
    pub left: Option<Rc<RefCell<TreeNode>>>,
    pub right: Option<Rc<RefCell<TreeNode>>>,
}

impl TreeNode {
    #[inline]
    pub fn new(val: i32) -> Self {
        TreeNode {
            val,
            left: None,
            right: None,
        }
    }
}

pub struct Solution;

impl Solution {
    /// Iterative Preorder Traversal: Root -> Left -> Right
    pub fn preorder_traversal(root: Option<Rc<RefCell<TreeNode>>>) -> Vec<i32> {
        let mut result = Vec::new();
        let mut stack = Vec::new();

        if let Some(node) = root {
            stack.push(node);
        }

        while let Some(curr) = stack.pop() {
            let node = curr.borrow();
            result.push(node.val);

            // Push right first so that left is processed first
            if let Some(ref right) = node.right {
                stack.push(Rc::clone(right));
            }
            if let Some(ref left) = node.left {
                stack.push(Rc::clone(left));
            }
        }

        result
    }
}
